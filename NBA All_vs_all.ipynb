# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import csv
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

nba_team_data = {
 'Team': [],
 'Matchup': [],
 'Game_date': [],
 'W_L': [],
 'Min': [],
 'Pts': [],
 'Fgm': [],
 'Fga': [],
 'Fg_p': [],
 'Three_pm': [],
 'Three_pa': [],
 'Threep_p': [],
 'Ftm': [],
 'Fta': [],
 'Ft_p': [],
 'Oreb': [],
 'Dreb': [],
 'Reb': [],
 'Ast': [],
 'Stl': [],
 'Blk': [],
 'Tov': [],
 'Pf': [],
 'Plus_Minus': []
}

nba_team_prep = {
    'Team1': [],
    'Team2': [],
    ## team1, team2, mean(team1), mean(team2), dif(mean(team1, team 2))
    #
    'Dif_Team1_Team2': [],
    'Win_Loose': [],
    'Point_Diff': []
}

n = pd.read_csv('nba2020.csv')
#format the date and outcome
n['Game_date'] = n['Game_date'].apply(lambda x: datetime.strptime(x.strip(),'%m/%d/%Y'))
n['W_L'] = n['W_L'].apply(lambda x: '1' if x=='W' else '0')

# %%
#ntp = [[i, j,'','',''] for i in teams for j in teams if i !=j]
teams = n['Team'].unique().tolist()
teams = [x for x in teams]
ntp = nba_team_prep
pairs = [[i, j,'',''] for i in teams for j in teams if i !=j]

# %%
ntp = [[i,j,n[(n['Team'] == i)].mean(axis = 0) - n[(n['Team'] == j)].mean(axis = 0),'',''] for i in teams for j in teams if i !=j]

# %%
#who wins

# %%
#Train

#prepare data for win/los
y = n['W_L']
n1 = n.drop('W_L', axis = 1) 
m = n1.to_numpy()
X = m[:,4:]

#prepare data for point difference


#train model for win/loss

lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(X, y)

#train model for point difference
mp = n.to_numpy()
X_points = m[:,5:]
y_points = n['Pts']

lasso_reg_points = Lasso(alpha=0.1)
lasso_reg_points.fit(X_points, y_points)
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
for game in range(len(pairs)):
    x = (np.asarray(ntp[game][2])[1:]).reshape(1,-1)
    xp = (np.asarray(ntp[game][2])[2:]).reshape(1,-1)
    pairs[game][2] = np.round(lasso_reg.predict(x)[0], decimals=1)
    pairs[game][3] = np.round(lasso_reg_points.predict(xp)[0], decimals=1)

# %%
pairs
# Out:
# [['NYK', 'ATL', 0.6, -6.5],
#  ['NYK', 'DET', 0.5, -2.0],
#  ['NYK', 'PHI', 0.3, -4.3],
#  ['NYK', 'DEN', 0.3, -5.0],
#  ['NYK', 'DAL', 0.2, -10.9],
#  ['NYK', 'CHA', 0.6, 2.1],
#  ['NYK', 'MIA', 0.3, -7.0],
#  ['NYK', 'SAS', 0.4, -8.0],
#  ['NYK', 'ORL', 0.4, -0.9],
#  ['NYK', 'MEM', 0.4, -7.2],
#  ['NYK', 'CHI', 0.5, -1.8],
#  ['NYK', 'CLE', 0.6, -1.3],
#  ['NYK', 'MIN', 0.5, -8.2],
#  ['NYK', 'HOU', 0.3, -12.7],
#  ['NYK', 'WAS', 0.5, -10.1],
#  ['NYK', 'BOS', 0.2, -7.4],
#  ['NYK', 'IND', 0.3, -4.1],
#  ['NYK', 'LAC', 0.2, -11.2],
#  ['NYK', 'GSW', 0.6, -1.3],
#  ['NYK', 'BKN', 0.4, -5.8],
#  ['NYK', 'LAL', 0.2, -8.6],
#  ['NYK', 'PHX', 0.4, -7.3],
#  ['NYK', 'POR', 0.4, -8.3],
#  ['NYK', 'TOR', 0.2, -7.8],
#  ['NYK', 'UTA', 0.3, -5.2],
#  ['NYK', 'MIL', 0.1, -13.3],
#  ['NYK', 'OKC', 0.3, -5.2],
#  ['NYK', 'SAC', 0.5, -3.5],
#  ['NYK', 'NOP', 0.4, -11.0],
#  ['ATL', 'NYK', 0.5, 5.2],
#  ['ATL', 'DET', 0.4, 3.8],
#  ['ATL', 'PHI', 0.3, 1.6],
#  ['ATL', 'DEN', 0.3, 0.8],
#  ['ATL', 'DAL', 0.2, -5.0],
#  ['ATL', 'CHA', 0.5, 7.9],
#  ['ATL', 'MIA', 0.2, -1.1],
#  ['ATL', 'SAS', 0.4, -2.1],
#  ['ATL', 'ORL', 0.3, 5.0],
#  ['ATL', 'MEM', 0.4, -1.3],
#  ['ATL', 'CHI', 0.4, 4.0],
#  ['ATL', 'CLE', 0.6, 4.6],
#  ['ATL', 'MIN', 0.5, -2.3],
#  ['ATL', 'HOU', 0.2, -6.8],
#  ['ATL', 'WAS', 0.5, -4.2],
#  ['ATL', 'BOS', 0.2, -1.5],
#  ['ATL', 'IND', 0.3, 1.8],
#  ['ATL', 'LAC', 0.1, -5.3],
#  ['ATL', 'GSW', 0.6, 4.6],
#  ['ATL', 'BKN', 0.4, 0.1],
#  ['ATL', 'LAL', 0.1, -2.7],
#  ['ATL', 'PHX', 0.4, -1.5],
#  ['ATL', 'POR', 0.4, -2.4],
#  ['ATL', 'TOR', 0.2, -2.0],
#  ['ATL', 'UTA', 0.3, 0.7],
#  ['ATL', 'MIL', 0.0, -7.4],
#  ['ATL', 'OKC', 0.3, 0.6],
#  ['ATL', 'SAC', 0.4, 2.3],
#  ['ATL', 'NOP', 0.4, -5.1],
#  ['DET', 'NYK', 0.6, 0.7],
#  ['DET', 'ATL', 0.7, -5.2],
#  ['DET', 'PHI', 0.4, -2.9],
#  ['DET', 'DEN', 0.4, -3.7],
#  ['DET', 'DAL', 0.3, -9.5],
#  ['DET', 'CHA', 0.6, 3.4],
#  ['DET', 'MIA', 0.4, -5.6],
#  ['DET', 'SAS', 0.5, -6.6],
#  ['DET', 'ORL', 0.5, 0.5],
#  ['DET', 'MEM', 0.5, -5.8],
#  ['DET', 'CHI', 0.6, -0.5],
#  ['DET', 'CLE', 0.7, 0.1],
#  ['DET', 'MIN', 0.6, -6.8],
#  ['DET', 'HOU', 0.4, -11.3],
#  ['DET', 'WAS', 0.6, -8.7],
#  ['DET', 'BOS', 0.3, -6.0],
#  ['DET', 'IND', 0.4, -2.7],
#  ['DET', 'LAC', 0.3, -9.8],
#  ['DET', 'GSW', 0.7, 0.1],
#  ['DET', 'BKN', 0.5, -4.4],
#  ['DET', 'LAL', 0.3, -7.2],
#  ['DET', 'PHX', 0.5, -6.0],
#  ['DET', 'POR', 0.5, -6.9],
#  ['DET', 'TOR', 0.3, -6.5],
#  ['DET', 'UTA', 0.4, -3.8],
#  ['DET', 'MIL', 0.2, -11.9],
#  ['DET', 'OKC', 0.4, -3.9],
#  ['DET', 'SAC', 0.5, -2.2],
#  ['DET', 'NOP', 0.5, -9.6],
#  ['PHI', 'NYK', 0.8, 3.0],
#  ['PHI', 'ATL', 0.8, -2.9],
#  ['PHI', 'DET', 0.7, 1.6],
#  ['PHI', 'DEN', 0.5, -1.4],
#  ['PHI', 'DAL', 0.5, -7.3],
#  ['PHI', 'CHA', 0.8, 5.7],
#  ['PHI', 'MIA', 0.5, -3.4],
#  ['PHI', 'SAS', 0.7, -4.4],
#  ['PHI', 'ORL', 0.6, 2.7],
#  ['PHI', 'MEM', 0.7, -3.5],
#  ['PHI', 'CHI', 0.7, 1.8],
#  ['PHI', 'CLE', 0.8, 2.3],
#  ['PHI', 'MIN', 0.7, -4.6],
#  ['PHI', 'HOU', 0.5, -9.1],
#  ['PHI', 'WAS', 0.7, -6.5],
#  ['PHI', 'BOS', 0.5, -3.8],
#  ['PHI', 'IND', 0.6, -0.5],
#  ['PHI', 'LAC', 0.4, -7.6],
#  ['PHI', 'GSW', 0.9, 2.3],
#  ['PHI', 'BKN', 0.6, -2.1],
#  ['PHI', 'LAL', 0.4, -5.0],
#  ['PHI', 'PHX', 0.6, -3.7],
#  ['PHI', 'POR', 0.7, -4.6],
#  ['PHI', 'TOR', 0.5, -4.2],
#  ['PHI', 'UTA', 0.5, -1.6],
#  ['PHI', 'MIL', 0.3, -9.7],
#  ['PHI', 'OKC', 0.5, -1.6],
#  ['PHI', 'SAC', 0.7, 0.1],
#  ['PHI', 'NOP', 0.7, -7.4],
#  ['DEN', 'NYK', 0.8, 3.7],
#  ['DEN', 'ATL', 0.9, -2.2],
#  ['DEN', 'DET', 0.7, 2.3],
#  ['DEN', 'PHI', 0.6, 0.1],
#  ['DEN', 'DAL', 0.5, -6.5],
#  ['DEN', 'CHA', 0.8, 6.4],
#  ['DEN', 'MIA', 0.5, -2.6],
#  ['DEN', 'SAS', 0.7, -3.6],
#  ['DEN', 'ORL', 0.6, 3.5],
#  ['DEN', 'MEM', 0.7, -2.8],
#  ['DEN', 'CHI', 0.7, 2.5],
#  ['DEN', 'CLE', 0.8, 3.1],
#  ['DEN', 'MIN', 0.8, -3.8],
#  ['DEN', 'HOU', 0.5, -8.3],
#  ['DEN', 'WAS', 0.7, -5.7],
#  ['DEN', 'BOS', 0.5, -3.0],
#  ['DEN', 'IND', 0.6, 0.3],
#  ['DEN', 'LAC', 0.4, -6.8],
#  ['DEN', 'GSW', 0.9, 3.1],
#  ['DEN', 'BKN', 0.7, -1.4],
#  ['DEN', 'LAL', 0.4, -4.2],
#  ['DEN', 'PHX', 0.7, -3.0],
#  ['DEN', 'POR', 0.7, -3.9],
#  ['DEN', 'TOR', 0.5, -3.5],
#  ['DEN', 'UTA', 0.6, -0.8],
#  ['DEN', 'MIL', 0.3, -8.9],
#  ['DEN', 'OKC', 0.6, -0.9],
#  ['DEN', 'SAC', 0.7, 0.8],
#  ['DEN', 'NOP', 0.7, -6.6],
#  ['DAL', 'NYK', 0.9, 9.6],
#  ['DAL', 'ATL', 0.9, 3.7],
#  ['DAL', 'DET', 0.8, 8.2],
#  ['DAL', 'PHI', 0.6, 6.0],
#  ['DAL', 'DEN', 0.6, 5.2],
#  ['DAL', 'CHA', 0.9, 12.3],
#  ['DAL', 'MIA', 0.6, 3.3],
#  ['DAL', 'SAS', 0.7, 2.3],
#  ['DAL', 'ORL', 0.7, 9.4],
#  ['DAL', 'MEM', 0.8, 3.1],
#  ['DAL', 'CHI', 0.8, 8.4],
#  ['DAL', 'CLE', 0.9, 9.0],
#  ['DAL', 'MIN', 0.8, 2.1],
#  ['DAL', 'HOU', 0.6, -2.4],
#  ['DAL', 'WAS', 0.8, 0.2],
#  ['DAL', 'BOS', 0.6, 2.9],
#  ['DAL', 'IND', 0.7, 6.2],
#  ['DAL', 'LAC', 0.5, -0.9],
#  ['DAL', 'GSW', 1.0, 9.0],
#  ['DAL', 'BKN', 0.7, 4.5],
#  ['DAL', 'LAL', 0.5, 1.7],
#  ['DAL', 'PHX', 0.7, 2.9],
#  ['DAL', 'POR', 0.8, 2.0],
#  ['DAL', 'TOR', 0.6, 2.4],
#  ['DAL', 'UTA', 0.6, 5.1],
#  ['DAL', 'MIL', 0.4, -3.1],
#  ['DAL', 'OKC', 0.6, 5.0],
#  ['DAL', 'SAC', 0.8, 6.7],
#  ['DAL', 'NOP', 0.7, -0.7],
#  ['CHA', 'NYK', 0.5, -3.4],
#  ['CHA', 'ATL', 0.6, -9.3],
#  ['CHA', 'DET', 0.5, -4.7],
#  ['CHA', 'PHI', 0.3, -7.0],
#  ['CHA', 'DEN', 0.3, -7.8],
#  ['CHA', 'DAL', 0.2, -13.6],
#  ['CHA', 'MIA', 0.3, -9.7],
#  ['CHA', 'SAS', 0.4, -10.7],
#  ['CHA', 'ORL', 0.4, -3.6],
#  ['CHA', 'MEM', 0.4, -9.9],
#  ['CHA', 'CHI', 0.5, -4.6],
#  ['CHA', 'CLE', 0.6, -4.0],
#  ['CHA', 'MIN', 0.5, -10.9],
#  ['CHA', 'HOU', 0.3, -15.4],
#  ['CHA', 'WAS', 0.5, -12.8],
#  ['CHA', 'BOS', 0.2, -10.1],
#  ['CHA', 'IND', 0.3, -6.8],
#  ['CHA', 'LAC', 0.2, -13.9],
#  ['CHA', 'GSW', 0.6, -4.0],
#  ['CHA', 'BKN', 0.4, -8.5],
#  ['CHA', 'LAL', 0.2, -11.3],
#  ['CHA', 'PHX', 0.4, -10.1],
#  ['CHA', 'POR', 0.4, -11.0],
#  ['CHA', 'TOR', 0.2, -10.6],
#  ['CHA', 'UTA', 0.3, -7.9],
#  ['CHA', 'MIL', 0.1, -16.0],
#  ['CHA', 'OKC', 0.3, -8.0],
#  ['CHA', 'SAC', 0.5, -6.2],
#  ['CHA', 'NOP', 0.4, -13.7],
#  ['MIA', 'NYK', 0.8, 5.7],
#  ['MIA', 'ATL', 0.9, -0.2],
#  ['MIA', 'DET', 0.7, 4.3],
#  ['MIA', 'PHI', 0.6, 2.1],
#  ['MIA', 'DEN', 0.6, 1.3],
#  ['MIA', 'DAL', 0.5, -4.6],
#  ['MIA', 'CHA', 0.8, 8.4],
#  ['MIA', 'SAS', 0.7, -1.7],
#  ['MIA', 'ORL', 0.7, 5.4],
#  ['MIA', 'MEM', 0.7, -0.8],
#  ['MIA', 'CHI', 0.7, 4.5],
#  ['MIA', 'CLE', 0.9, 5.0],
#  ['MIA', 'MIN', 0.8, -1.8],
#  ['MIA', 'HOU', 0.6, -6.4],
#  ['MIA', 'WAS', 0.8, -3.7],
#  ['MIA', 'BOS', 0.5, -1.1],
#  ['MIA', 'IND', 0.6, 2.2],
#  ['MIA', 'LAC', 0.5, -4.9],
#  ['MIA', 'GSW', 0.9, 5.0],
#  ['MIA', 'BKN', 0.7, 0.6],
#  ['MIA', 'LAL', 0.5, -2.2],
#  ['MIA', 'PHX', 0.7, -1.0],
#  ['MIA', 'POR', 0.7, -1.9],
#  ['MIA', 'TOR', 0.5, -1.5],
#  ['MIA', 'UTA', 0.6, 1.1],
#  ['MIA', 'MIL', 0.3, -7.0],
#  ['MIA', 'OKC', 0.6, 1.1],
#  ['MIA', 'SAC', 0.7, 2.8],
#  ['MIA', 'NOP', 0.7, -4.6],
#  ['SAS', 'NYK', 0.7, 6.7],
#  ['SAS', 'ATL', 0.7, 0.8],
#  ['SAS', 'DET', 0.6, 5.3],
#  ['SAS', 'PHI', 0.5, 3.0],
#  ['SAS', 'DEN', 0.4, 2.3],
#  ['SAS', 'DAL', 0.4, -3.6],
#  ['SAS', 'CHA', 0.7, 9.4],
#  ['SAS', 'MIA', 0.4, 0.3],
#  ['SAS', 'ORL', 0.5, 6.4],
#  ['SAS', 'MEM', 0.6, 0.2],
#  ['SAS', 'CHI', 0.6, 5.5],
#  ['SAS', 'CLE', 0.7, 6.0],
#  ['SAS', 'MIN', 0.6, -0.8],
#  ['SAS', 'HOU', 0.4, -5.4],
#  ['SAS', 'WAS', 0.6, -2.7],
#  ['SAS', 'BOS', 0.4, -0.1],
#  ['SAS', 'IND', 0.5, 3.2],
#  ['SAS', 'LAC', 0.3, -3.9],
#  ['SAS', 'GSW', 0.8, 6.0],
#  ['SAS', 'BKN', 0.5, 1.6],
#  ['SAS', 'LAL', 0.3, -1.2],
#  ['SAS', 'PHX', 0.5, -0.0],
#  ['SAS', 'POR', 0.6, -0.9],
#  ['SAS', 'TOR', 0.4, -0.5],
#  ['SAS', 'UTA', 0.4, 2.1],
#  ['SAS', 'MIL', 0.2, -6.0],
#  ['SAS', 'OKC', 0.4, 2.1],
#  ['SAS', 'SAC', 0.6, 3.8],
#  ['SAS', 'NOP', 0.6, -3.6],
#  ['ORL', 'NYK', 0.7, -0.4],
#  ['ORL', 'ATL', 0.8, -6.3],
#  ['ORL', 'DET', 0.6, -1.8],
#  ['ORL', 'PHI', 0.5, -4.0],
#  ['ORL', 'DEN', 0.5, -4.8],
#  ['ORL', 'DAL', 0.4, -10.7],
#  ['ORL', 'CHA', 0.7, 2.3],
#  ['ORL', 'MIA', 0.4, -6.7],
#  ['ORL', 'SAS', 0.6, -7.7],
#  ['ORL', 'MEM', 0.6, -6.9],
#  ['ORL', 'CHI', 0.6, -1.6],
#  ['ORL', 'CLE', 0.8, -1.0],
#  ['ORL', 'MIN', 0.7, -7.9],
#  ['ORL', 'HOU', 0.5, -12.5],
#  ['ORL', 'WAS', 0.7, -9.8],
#  ['ORL', 'BOS', 0.4, -7.1],
#  ['ORL', 'IND', 0.5, -3.8],
#  ['ORL', 'LAC', 0.4, -10.9],
#  ['ORL', 'GSW', 0.8, -1.0],
#  ['ORL', 'BKN', 0.6, -5.5],
#  ['ORL', 'LAL', 0.3, -8.3],
#  ['ORL', 'PHX', 0.6, -7.1],
#  ['ORL', 'POR', 0.6, -8.0],
#  ['ORL', 'TOR', 0.4, -7.6],
#  ['ORL', 'UTA', 0.5, -4.9],
#  ['ORL', 'MIL', 0.2, -13.1],
#  ['ORL', 'OKC', 0.5, -5.0],
#  ['ORL', 'SAC', 0.6, -3.3],
#  ['ORL', 'NOP', 0.6, -10.7],
#  ['MEM', 'NYK', 0.7, 5.8],
#  ['MEM', 'ATL', 0.7, -0.0],
#  ['MEM', 'DET', 0.6, 4.5],
#  ['MEM', 'PHI', 0.4, 2.2],
#  ['MEM', 'DEN', 0.4, 1.5],
#  ['MEM', 'DAL', 0.4, -4.4],
#  ['MEM', 'CHA', 0.7, 8.6],
#  ['MEM', 'MIA', 0.4, -0.5],
#  ['MEM', 'SAS', 0.5, -1.5],
#  ['MEM', 'ORL', 0.5, 5.6],
#  ['MEM', 'CHI', 0.6, 4.7],
#  ['MEM', 'CLE', 0.7, 5.2],
#  ['MEM', 'MIN', 0.6, -1.7],
#  ['MEM', 'HOU', 0.4, -6.2],
#  ['MEM', 'WAS', 0.6, -3.6],
#  ['MEM', 'BOS', 0.4, -0.9],
#  ['MEM', 'IND', 0.5, 2.4],
#  ['MEM', 'LAC', 0.3, -4.7],
#  ['MEM', 'GSW', 0.8, 5.2],
#  ['MEM', 'BKN', 0.5, 0.8],
#  ['MEM', 'LAL', 0.3, -2.1],
#  ['MEM', 'PHX', 0.5, -0.8],
#  ['MEM', 'POR', 0.6, -1.8],
#  ['MEM', 'TOR', 0.4, -1.3],
#  ['MEM', 'UTA', 0.4, 1.3],
#  ['MEM', 'MIL', 0.2, -6.8],
#  ['MEM', 'OKC', 0.4, 1.3],
#  ['MEM', 'SAC', 0.6, 3.0],
#  ['MEM', 'NOP', 0.5, -4.5],
#  ['CHI', 'NYK', 0.6, 0.5],
#  ['CHI', 'ATL', 0.7, -5.4],
#  ['CHI', 'DET', 0.6, -0.8],
#  ['CHI', 'PHI', 0.4, -3.1],
#  ['CHI', 'DEN', 0.4, -3.9],
#  ['CHI', 'DAL', 0.3, -9.7],
#  ['CHI', 'CHA', 0.6, 3.2],
#  ['CHI', 'MIA', 0.4, -5.8],
#  ['CHI', 'SAS', 0.5, -6.8],
#  ['CHI', 'ORL', 0.5, 0.3],
#  ['CHI', 'MEM', 0.5, -6.0],
#  ['CHI', 'CLE', 0.7, -0.1],
#  ['CHI', 'MIN', 0.6, -7.0],
#  ['CHI', 'HOU', 0.4, -11.5],
#  ['CHI', 'WAS', 0.6, -8.9],
#  ['CHI', 'BOS', 0.3, -6.2],
#  ['CHI', 'IND', 0.4, -2.9],
#  ['CHI', 'LAC', 0.3, -10.0],
#  ['CHI', 'GSW', 0.7, -0.1],
#  ['CHI', 'BKN', 0.5, -4.6],
#  ['CHI', 'LAL', 0.3, -7.4],
#  ['CHI', 'PHX', 0.5, -6.2],
#  ['CHI', 'POR', 0.5, -7.1],
#  ['CHI', 'TOR', 0.3, -6.7],
#  ['CHI', 'UTA', 0.4, -4.0],
#  ['CHI', 'MIL', 0.2, -12.1],
#  ['CHI', 'OKC', 0.4, -4.1],
#  ['CHI', 'SAC', 0.5, -2.3],
#  ['CHI', 'NOP', 0.5, -9.8],
#  ['CLE', 'NYK', 0.5, -0.0],
#  ['CLE', 'ATL', 0.6, -5.9],
#  ['CLE', 'DET', 0.4, -1.4],
#  ['CLE', 'PHI', 0.3, -3.7],
#  ['CLE', 'DEN', 0.3, -4.4],
#  ['CLE', 'DAL', 0.2, -10.3],
#  ['CLE', 'CHA', 0.5, 2.7],
#  ['CLE', 'MIA', 0.2, -6.4],
#  ['CLE', 'SAS', 0.4, -7.4],
#  ['CLE', 'ORL', 0.4, -0.3],
#  ['CLE', 'MEM', 0.4, -6.5],
#  ['CLE', 'CHI', 0.4, -1.2],
#  ['CLE', 'MIN', 0.5, -7.5],
#  ['CLE', 'HOU', 0.3, -12.1],
#  ['CLE', 'WAS', 0.5, -9.4],
#  ['CLE', 'BOS', 0.2, -6.8],
#  ['CLE', 'IND', 0.3, -3.5],
#  ['CLE', 'LAC', 0.2, -10.6],
#  ['CLE', 'GSW', 0.6, -0.7],
#  ['CLE', 'BKN', 0.4, -5.1],
#  ['CLE', 'LAL', 0.1, -7.9],
#  ['CLE', 'PHX', 0.4, -6.7],
#  ['CLE', 'POR', 0.4, -7.6],
#  ['CLE', 'TOR', 0.2, -7.2],
#  ['CLE', 'UTA', 0.3, -4.6],
#  ['CLE', 'MIL', 0.0, -12.7],
#  ['CLE', 'OKC', 0.3, -4.6],
#  ['CLE', 'SAC', 0.4, -2.9],
#  ['CLE', 'NOP', 0.4, -10.3],
#  ['MIN', 'NYK', 0.6, 6.9],
#  ['MIN', 'ATL', 0.7, 1.0],
#  ['MIN', 'DET', 0.5, 5.5],
#  ['MIN', 'PHI', 0.4, 3.2],
#  ['MIN', 'DEN', 0.4, 2.5],
#  ['MIN', 'DAL', 0.3, -3.4],
#  ['MIN', 'CHA', 0.6, 9.6],
#  ['MIN', 'MIA', 0.3, 0.5],
#  ['MIN', 'SAS', 0.5, -0.5],
#  ['MIN', 'ORL', 0.4, 6.6],
#  ['MIN', 'MEM', 0.5, 0.3],
#  ['MIN', 'CHI', 0.5, 5.7],
#  ['MIN', 'CLE', 0.6, 6.2],
#  ['MIN', 'HOU', 0.3, -5.2],
#  ['MIN', 'WAS', 0.5, -2.6],
#  ['MIN', 'BOS', 0.3, 0.1],
#  ['MIN', 'IND', 0.4, 3.4],
#  ['MIN', 'LAC', 0.2, -3.7],
#  ['MIN', 'GSW', 0.7, 6.2],
#  ['MIN', 'BKN', 0.5, 1.8],
#  ['MIN', 'LAL', 0.2, -1.1],
#  ['MIN', 'PHX', 0.5, 0.2],
#  ['MIN', 'POR', 0.5, -0.7],
#  ['MIN', 'TOR', 0.3, -0.3],
#  ['MIN', 'UTA', 0.4, 2.3],
#  ['MIN', 'MIL', 0.1, -5.8],
#  ['MIN', 'OKC', 0.4, 2.3],
#  ['MIN', 'SAC', 0.5, 4.0],
#  ['MIN', 'NOP', 0.5, -3.5],
#  ['HOU', 'NYK', 0.8, 11.4],
#  ['HOU', 'ATL', 0.9, 5.5],
#  ['HOU', 'DET', 0.7, 10.0],
#  ['HOU', 'PHI', 0.6, 7.8],
#  ['HOU', 'DEN', 0.6, 7.0],
#  ['HOU', 'DAL', 0.5, 1.1],
#  ['HOU', 'CHA', 0.8, 14.1],
#  ['HOU', 'MIA', 0.5, 5.1],
#  ['HOU', 'SAS', 0.7, 4.1],
#  ['HOU', 'ORL', 0.7, 11.1],
#  ['HOU', 'MEM', 0.7, 4.9],
#  ['HOU', 'CHI', 0.7, 10.2],
#  ['HOU', 'CLE', 0.9, 10.8],
#  ['HOU', 'MIN', 0.8, 3.9],
#  ['HOU', 'WAS', 0.8, 2.0],
#  ['HOU', 'BOS', 0.5, 4.6],
#  ['HOU', 'IND', 0.6, 8.0],
#  ['HOU', 'LAC', 0.5, 0.8],
#  ['HOU', 'GSW', 0.9, 10.8],
#  ['HOU', 'BKN', 0.7, 6.3],
#  ['HOU', 'LAL', 0.4, 3.5],
#  ['HOU', 'PHX', 0.7, 4.7],
#  ['HOU', 'POR', 0.7, 3.8],
#  ['HOU', 'TOR', 0.5, 4.2],
#  ['HOU', 'UTA', 0.6, 6.9],
#  ['HOU', 'MIL', 0.3, -1.3],
#  ['HOU', 'OKC', 0.6, 6.8],
#  ['HOU', 'SAC', 0.7, 8.5],
#  ['HOU', 'NOP', 0.7, 1.1],
#  ['WAS', 'NYK', 0.6, 8.7],
#  ['WAS', 'ATL', 0.7, 2.9],
#  ['WAS', 'DET', 0.5, 7.4],
#  ['WAS', 'PHI', 0.4, 5.1],
#  ['WAS', 'DEN', 0.4, 4.4],
#  ['WAS', 'DAL', 0.3, -1.5],
#  ['WAS', 'CHA', 0.6, 11.5],
#  ['WAS', 'MIA', 0.3, 2.4],
#  ['WAS', 'SAS', 0.5, 1.4],
#  ['WAS', 'ORL', 0.5, 8.5],
#  ['WAS', 'MEM', 0.5, 2.2],
#  ['WAS', 'CHI', 0.5, 7.6],
#  ['WAS', 'CLE', 0.7, 8.1],
#  ['WAS', 'MIN', 0.6, 1.2],
#  ['WAS', 'HOU', 0.4, -3.3],
#  ['WAS', 'BOS', 0.3, 2.0],
#  ['WAS', 'IND', 0.4, 5.3],
#  ['WAS', 'LAC', 0.3, -1.8],
#  ['WAS', 'GSW', 0.7, 8.1],
#  ['WAS', 'BKN', 0.5, 3.7],
#  ['WAS', 'LAL', 0.2, 0.8],
#  ['WAS', 'PHX', 0.5, 2.1],
#  ['WAS', 'POR', 0.5, 1.2],
#  ['WAS', 'TOR', 0.3, 1.6],
#  ['WAS', 'UTA', 0.4, 4.2],
#  ['WAS', 'MIL', 0.1, -3.9],
#  ['WAS', 'OKC', 0.4, 4.2],
#  ['WAS', 'SAC', 0.5, 5.9],
#  ['WAS', 'NOP', 0.5, -1.6],
#  ['BOS', 'NYK', 0.9, 6.1],
#  ['BOS', 'ATL', 0.9, 0.2],
#  ['BOS', 'DET', 0.8, 4.7],
#  ['BOS', 'PHI', 0.6, 2.5],
#  ['BOS', 'DEN', 0.6, 1.7],
#  ['BOS', 'DAL', 0.5, -4.2],
#  ['BOS', 'CHA', 0.9, 8.8],
#  ['BOS', 'MIA', 0.6, -0.2],
#  ['BOS', 'SAS', 0.7, -1.2],
#  ['BOS', 'ORL', 0.7, 5.8],
#  ['BOS', 'MEM', 0.7, -0.4],
#  ['BOS', 'CHI', 0.8, 4.9],
#  ['BOS', 'CLE', 0.9, 5.5],
#  ['BOS', 'MIN', 0.8, -1.4],
#  ['BOS', 'HOU', 0.6, -6.0],
#  ['BOS', 'WAS', 0.8, -3.3],
#  ['BOS', 'IND', 0.7, 2.7],
#  ['BOS', 'LAC', 0.5, -4.5],
#  ['BOS', 'GSW', 0.9, 5.5],
#  ['BOS', 'BKN', 0.7, 1.0],
#  ['BOS', 'LAL', 0.5, -1.8],
#  ['BOS', 'PHX', 0.7, -0.6],
#  ['BOS', 'POR', 0.8, -1.5],
#  ['BOS', 'TOR', 0.5, -1.1],
#  ['BOS', 'UTA', 0.6, 1.6],
#  ['BOS', 'MIL', 0.4, -6.6],
#  ['BOS', 'OKC', 0.6, 1.5],
#  ['BOS', 'SAC', 0.8, 3.2],
#  ['BOS', 'NOP', 0.7, -4.2],
#  ['IND', 'NYK', 0.8, 2.8],
#  ['IND', 'ATL', 0.8, -3.1],
#  ['IND', 'DET', 0.7, 1.4],
#  ['IND', 'PHI', 0.5, -0.8],
#  ['IND', 'DEN', 0.5, -1.6],
#  ['IND', 'DAL', 0.4, -7.5],
#  ['IND', 'CHA', 0.8, 5.5],
#  ['IND', 'MIA', 0.5, -3.5],
#  ['IND', 'SAS', 0.6, -4.5],
#  ['IND', 'ORL', 0.6, 2.5],
#  ['IND', 'MEM', 0.6, -3.7],
#  ['IND', 'CHI', 0.7, 1.6],
#  ['IND', 'CLE', 0.8, 2.2],
#  ['IND', 'MIN', 0.7, -4.7],
#  ['IND', 'HOU', 0.5, -9.3],
#  ['IND', 'WAS', 0.7, -6.6],
#  ['IND', 'BOS', 0.4, -4.0],
#  ['IND', 'LAC', 0.4, -7.8],
#  ['IND', 'GSW', 0.8, 2.1],
#  ['IND', 'BKN', 0.6, -2.3],
#  ['IND', 'LAL', 0.4, -5.1],
#  ['IND', 'PHX', 0.6, -3.9],
#  ['IND', 'POR', 0.7, -4.8],
#  ['IND', 'TOR', 0.4, -4.4],
#  ['IND', 'UTA', 0.5, -1.8],
#  ['IND', 'MIL', 0.3, -9.9],
#  ['IND', 'OKC', 0.5, -1.8],
#  ['IND', 'SAC', 0.7, -0.1],
#  ['IND', 'NOP', 0.6, -7.5],
#  ['LAC', 'NYK', 0.9, 9.9],
#  ['LAC', 'ATL', 1.0, 4.0],
#  ['LAC', 'DET', 0.8, 8.5],
#  ['LAC', 'PHI', 0.7, 6.3],
#  ['LAC', 'DEN', 0.7, 5.5],
#  ['LAC', 'DAL', 0.6, -0.4],
#  ['LAC', 'CHA', 0.9, 12.6],
#  ['LAC', 'MIA', 0.6, 3.6],
#  ['LAC', 'SAS', 0.8, 2.6],
#  ['LAC', 'ORL', 0.8, 9.6],
#  ['LAC', 'MEM', 0.8, 3.4],
#  ['LAC', 'CHI', 0.8, 8.7],
#  ['LAC', 'CLE', 1.0, 9.3],
#  ['LAC', 'MIN', 0.9, 2.4],
#  ['LAC', 'HOU', 0.7, -2.2],
#  ['LAC', 'WAS', 0.9, 0.5],
#  ['LAC', 'BOS', 0.6, 3.1],
#  ['LAC', 'IND', 0.7, 6.5],
#  ['LAC', 'GSW', 1.0, 9.3],
#  ['LAC', 'BKN', 0.8, 4.8],
#  ['LAC', 'LAL', 0.5, 2.0],
#  ['LAC', 'PHX', 0.8, 3.2],
#  ['LAC', 'POR', 0.8, 2.3],
#  ['LAC', 'TOR', 0.6, 2.7],
#  ['LAC', 'UTA', 0.7, 5.4],
#  ['LAC', 'MIL', 0.4, -2.8],
#  ['LAC', 'OKC', 0.7, 5.3],
#  ['LAC', 'SAC', 0.8, 7.0],
#  ['LAC', 'NOP', 0.8, -0.4],
#  ['GSW', 'NYK', 0.5, -0.0],
#  ['GSW', 'ATL', 0.5, -5.9],
#  ['GSW', 'DET', 0.4, -1.4],
#  ['GSW', 'PHI', 0.3, -3.6],
#  ['GSW', 'DEN', 0.2, -4.4],
#  ['GSW', 'DAL', 0.2, -10.3],
#  ['GSW', 'CHA', 0.5, 2.7],
#  ['GSW', 'MIA', 0.2, -6.4],
#  ['GSW', 'SAS', 0.3, -7.3],
#  ['GSW', 'ORL', 0.3, -0.3],
#  ['GSW', 'MEM', 0.4, -6.5],
#  ['GSW', 'CHI', 0.4, -1.2],
#  ['GSW', 'CLE', 0.5, -0.6],
#  ['GSW', 'MIN', 0.4, -7.5],
#  ['GSW', 'HOU', 0.2, -12.1],
#  ['GSW', 'WAS', 0.4, -9.4],
#  ['GSW', 'BOS', 0.2, -6.8],
#  ['GSW', 'IND', 0.3, -3.5],
#  ['GSW', 'LAC', 0.1, -10.6],
#  ['GSW', 'BKN', 0.3, -5.1],
#  ['GSW', 'LAL', 0.1, -7.9],
#  ['GSW', 'PHX', 0.3, -6.7],
#  ['GSW', 'POR', 0.4, -7.6],
#  ['GSW', 'TOR', 0.2, -7.2],
#  ['GSW', 'UTA', 0.2, -4.6],
#  ['GSW', 'MIL', 0.0, -12.7],
#  ['GSW', 'OKC', 0.2, -4.6],
#  ['GSW', 'SAC', 0.4, -2.9],
#  ['GSW', 'NOP', 0.3, -10.3],
#  ['BKN', 'NYK', 0.7, 4.4],
#  ['BKN', 'ATL', 0.8, -1.4],
#  ['BKN', 'DET', 0.6, 3.1],
#  ['BKN', 'PHI', 0.5, 0.8],
#  ['BKN', 'DEN', 0.5, 0.1],
#  ['BKN', 'DAL', 0.4, -5.8],
#  ['BKN', 'CHA', 0.7, 7.1],
#  ['BKN', 'MIA', 0.4, -1.9],
#  ['BKN', 'SAS', 0.6, -2.9],
#  ['BKN', 'ORL', 0.5, 4.2],
#  ['BKN', 'MEM', 0.6, -2.1],
#  ['BKN', 'CHI', 0.6, 3.2],
#  ['BKN', 'CLE', 0.7, 3.8],
#  ['BKN', 'MIN', 0.7, -3.1],
#  ['BKN', 'HOU', 0.4, -7.6],
#  ['BKN', 'WAS', 0.6, -5.0],
#  ['BKN', 'BOS', 0.4, -2.3],
#  ['BKN', 'IND', 0.5, 1.0],
#  ['BKN', 'LAC', 0.3, -6.1],
#  ['BKN', 'GSW', 0.8, 3.8],
#  ['BKN', 'LAL', 0.3, -3.5],
#  ['BKN', 'PHX', 0.6, -2.3],
#  ['BKN', 'POR', 0.6, -3.2],
#  ['BKN', 'TOR', 0.4, -2.8],
#  ['BKN', 'UTA', 0.5, -0.1],
#  ['BKN', 'MIL', 0.2, -8.2],
#  ['BKN', 'OKC', 0.5, -0.1],
#  ['BKN', 'SAC', 0.6, 1.6],
#  ['BKN', 'NOP', 0.6, -5.9],
#  ['LAL', 'NYK', 0.9, 7.2],
#  ['LAL', 'ATL', 1.0, 1.4],
#  ['LAL', 'DET', 0.8, 5.9],
#  ['LAL', 'PHI', 0.7, 3.6],
#  ['LAL', 'DEN', 0.7, 2.9],
#  ['LAL', 'DAL', 0.6, -3.0],
#  ['LAL', 'CHA', 0.9, 10.0],
#  ['LAL', 'MIA', 0.7, 0.9],
#  ['LAL', 'SAS', 0.8, -0.1],
#  ['LAL', 'ORL', 0.8, 7.0],
#  ['LAL', 'MEM', 0.8, 0.7],
#  ['LAL', 'CHI', 0.8, 6.1],
#  ['LAL', 'CLE', 1.0, 6.6],
#  ['LAL', 'MIN', 0.9, -0.3],
#  ['LAL', 'HOU', 0.7, -4.8],
#  ['LAL', 'WAS', 0.9, -2.2],
#  ['LAL', 'BOS', 0.6, 0.5],
#  ['LAL', 'IND', 0.7, 3.8],
#  ['LAL', 'LAC', 0.6, -3.3],
#  ['LAL', 'GSW', 1.0, 6.6],
#  ['LAL', 'BKN', 0.8, 2.2],
#  ['LAL', 'PHX', 0.8, 0.6],
#  ['LAL', 'POR', 0.8, -0.4],
#  ['LAL', 'TOR', 0.6, 0.1],
#  ['LAL', 'UTA', 0.7, 2.7],
#  ['LAL', 'MIL', 0.4, -5.4],
#  ['LAL', 'OKC', 0.7, 2.7],
#  ['LAL', 'SAC', 0.8, 4.4],
#  ['LAL', 'NOP', 0.8, -3.1],
#  ['PHX', 'NYK', 0.7, 6.0],
#  ['PHX', 'ATL', 0.7, 0.1],
#  ['PHX', 'DET', 0.6, 4.7],
#  ['PHX', 'PHI', 0.5, 2.4],
#  ['PHX', 'DEN', 0.4, 1.6],
#  ['PHX', 'DAL', 0.4, -4.2],
#  ['PHX', 'CHA', 0.7, 8.7],
#  ['PHX', 'MIA', 0.4, -0.3],
#  ['PHX', 'SAS', 0.6, -1.3],
#  ['PHX', 'ORL', 0.5, 5.8],
#  ['PHX', 'MEM', 0.6, -0.5],
#  ['PHX', 'CHI', 0.6, 4.8],
#  ['PHX', 'CLE', 0.7, 5.4],
#  ['PHX', 'MIN', 0.6, -1.5],
#  ['PHX', 'HOU', 0.4, -6.0],
#  ['PHX', 'WAS', 0.6, -3.4],
#  ['PHX', 'BOS', 0.4, -0.7],
#  ['PHX', 'IND', 0.5, 2.6],
#  ['PHX', 'LAC', 0.3, -4.5],
#  ['PHX', 'GSW', 0.8, 5.4],
#  ['PHX', 'BKN', 0.5, 0.9],
#  ['PHX', 'LAL', 0.3, -1.9],
#  ['PHX', 'POR', 0.6, -1.6],
#  ['PHX', 'TOR', 0.4, -1.2],
#  ['PHX', 'UTA', 0.4, 1.5],
#  ['PHX', 'MIL', 0.2, -6.6],
#  ['PHX', 'OKC', 0.4, 1.4],
#  ['PHX', 'SAC', 0.6, 3.2],
#  ['PHX', 'NOP', 0.6, -4.3],
#  ['POR', 'NYK', 0.7, 6.9],
#  ['POR', 'ATL', 0.7, 1.1],
#  ['POR', 'DET', 0.6, 5.6],
#  ['POR', 'PHI', 0.4, 3.3],
#  ['POR', 'DEN', 0.4, 2.6],
#  ['POR', 'DAL', 0.3, -3.3],
#  ['POR', 'CHA', 0.7, 9.7],
#  ['POR', 'MIA', 0.4, 0.6],
#  ['POR', 'SAS', 0.5, -0.4],
#  ['POR', 'ORL', 0.5, 6.7],
#  ['POR', 'MEM', 0.5, 0.4],
#  ['POR', 'CHI', 0.6, 5.8],
#  ['POR', 'CLE', 0.7, 6.3],
#  ['POR', 'MIN', 0.6, -0.6],
#  ['POR', 'HOU', 0.4, -5.1],
#  ['POR', 'WAS', 0.6, -2.5],
#  ['POR', 'BOS', 0.3, 0.2],
#  ['POR', 'IND', 0.5, 3.5],
#  ['POR', 'LAC', 0.3, -3.6],
#  ['POR', 'GSW', 0.7, 6.3],
#  ['POR', 'BKN', 0.5, 1.8],
#  ['POR', 'LAL', 0.3, -1.0],
#  ['POR', 'PHX', 0.5, 0.3],
#  ['POR', 'TOR', 0.3, -0.2],
#  ['POR', 'UTA', 0.4, 2.4],
#  ['POR', 'MIL', 0.2, -5.7],
#  ['POR', 'OKC', 0.4, 2.4],
#  ['POR', 'SAC', 0.6, 4.1],
#  ['POR', 'NOP', 0.5, -3.4],
#  ['TOR', 'NYK', 0.9, 6.5],
#  ['TOR', 'ATL', 0.9, 0.6],
#  ['TOR', 'DET', 0.8, 5.2],
#  ['TOR', 'PHI', 0.7, 2.9],
#  ['TOR', 'DEN', 0.6, 2.1],
#  ['TOR', 'DAL', 0.6, -3.7],
#  ['TOR', 'CHA', 0.9, 9.2],
#  ['TOR', 'MIA', 0.6, 0.2],
#  ['TOR', 'SAS', 0.7, -0.8],
#  ['TOR', 'ORL', 0.7, 6.3],
#  ['TOR', 'MEM', 0.8, 0.0],
#  ['TOR', 'CHI', 0.8, 5.3],
#  ['TOR', 'CLE', 0.9, 5.9],
#  ['TOR', 'MIN', 0.8, -1.0],
#  ['TOR', 'HOU', 0.6, -5.5],
#  ['TOR', 'WAS', 0.8, -2.9],
#  ['TOR', 'BOS', 0.6, -0.2],
#  ['TOR', 'IND', 0.7, 3.1],
#  ['TOR', 'LAC', 0.5, -4.0],
#  ['TOR', 'GSW', 1.0, 5.9],
#  ['TOR', 'BKN', 0.7, 1.4],
#  ['TOR', 'LAL', 0.5, -1.4],
#  ['TOR', 'PHX', 0.7, -0.2],
#  ['TOR', 'POR', 0.8, -1.1],
#  ['TOR', 'UTA', 0.6, 2.0],
#  ['TOR', 'MIL', 0.4, -6.1],
#  ['TOR', 'OKC', 0.6, 1.9],
#  ['TOR', 'SAC', 0.8, 3.7],
#  ['TOR', 'NOP', 0.7, -3.8],
#  ['UTA', 'NYK', 0.8, 3.9],
#  ['UTA', 'ATL', 0.9, -2.0],
#  ['UTA', 'DET', 0.7, 2.5],
#  ['UTA', 'PHI', 0.6, 0.3],
#  ['UTA', 'DEN', 0.6, -0.5],
#  ['UTA', 'DAL', 0.5, -6.4],
#  ['UTA', 'CHA', 0.8, 6.6],
#  ['UTA', 'MIA', 0.5, -2.5],
#  ['UTA', 'SAS', 0.7, -3.4],
#  ['UTA', 'ORL', 0.6, 3.6],
#  ['UTA', 'MEM', 0.7, -2.6],
#  ['UTA', 'CHI', 0.7, 2.7],
#  ['UTA', 'CLE', 0.8, 3.3],
#  ['UTA', 'MIN', 0.8, -3.6],
#  ['UTA', 'HOU', 0.5, -8.2],
#  ['UTA', 'WAS', 0.7, -5.5],
#  ['UTA', 'BOS', 0.5, -2.9],
#  ['UTA', 'IND', 0.6, 0.4],
#  ['UTA', 'LAC', 0.4, -6.7],
#  ['UTA', 'GSW', 0.9, 3.2],
#  ['UTA', 'BKN', 0.7, -1.2],
#  ['UTA', 'LAL', 0.4, -4.0],
#  ['UTA', 'PHX', 0.7, -2.8],
#  ['UTA', 'POR', 0.7, -3.7],
#  ['UTA', 'TOR', 0.5, -3.3],
#  ['UTA', 'MIL', 0.3, -8.8],
#  ['UTA', 'OKC', 0.6, -0.7],
#  ['UTA', 'SAC', 0.7, 1.0],
#  ['UTA', 'NOP', 0.7, -6.4],
#  ['MIL', 'NYK', 1.0, 12.0],
#  ['MIL', 'ATL', 1.1, 6.1],
#  ['MIL', 'DET', 1.0, 10.6],
#  ['MIL', 'PHI', 0.8, 8.4],
#  ['MIL', 'DEN', 0.8, 7.6],
#  ['MIL', 'DAL', 0.7, 1.7],
#  ['MIL', 'CHA', 1.0, 14.7],
#  ['MIL', 'MIA', 0.8, 5.7],
#  ['MIL', 'SAS', 0.9, 4.7],
#  ['MIL', 'ORL', 0.9, 11.8],
#  ['MIL', 'MEM', 0.9, 5.5],
#  ['MIL', 'CHI', 1.0, 10.8],
#  ['MIL', 'CLE', 1.1, 11.4],
#  ['MIL', 'MIN', 1.0, 4.5],
#  ['MIL', 'HOU', 0.8, -0.0],
#  ['MIL', 'WAS', 1.0, 2.6],
#  ['MIL', 'BOS', 0.7, 5.3],
#  ['MIL', 'IND', 0.8, 8.6],
#  ['MIL', 'LAC', 0.7, 1.5],
#  ['MIL', 'GSW', 1.1, 11.4],
#  ['MIL', 'BKN', 0.9, 6.9],
#  ['MIL', 'LAL', 0.7, 4.1],
#  ['MIL', 'PHX', 0.9, 5.3],
#  ['MIL', 'POR', 0.9, 4.4],
#  ['MIL', 'TOR', 0.7, 4.8],
#  ['MIL', 'UTA', 0.8, 7.5],
#  ['MIL', 'OKC', 0.8, 7.4],
#  ['MIL', 'SAC', 0.9, 9.1],
#  ['MIL', 'NOP', 0.9, 1.7],
#  ['OKC', 'NYK', 0.8, 3.9],
#  ['OKC', 'ATL', 0.9, -2.0],
#  ['OKC', 'DET', 0.7, 2.5],
#  ['OKC', 'PHI', 0.6, 0.3],
#  ['OKC', 'DEN', 0.6, -0.5],
#  ['OKC', 'DAL', 0.5, -6.3],
#  ['OKC', 'CHA', 0.8, 6.6],
#  ['OKC', 'MIA', 0.5, -2.4],
#  ['OKC', 'SAS', 0.7, -3.4],
#  ['OKC', 'ORL', 0.6, 3.7],
#  ['OKC', 'MEM', 0.7, -2.6],
#  ['OKC', 'CHI', 0.7, 2.7],
#  ['OKC', 'CLE', 0.8, 3.3],
#  ['OKC', 'MIN', 0.8, -3.6],
#  ['OKC', 'HOU', 0.5, -8.1],
#  ['OKC', 'WAS', 0.7, -5.5],
#  ['OKC', 'BOS', 0.5, -2.8],
#  ['OKC', 'IND', 0.6, 0.5],
#  ['OKC', 'LAC', 0.4, -6.6],
#  ['OKC', 'GSW', 0.9, 3.3],
#  ['OKC', 'BKN', 0.7, -1.2],
#  ['OKC', 'LAL', 0.4, -4.0],
#  ['OKC', 'PHX', 0.7, -2.8],
#  ['OKC', 'POR', 0.7, -3.7],
#  ['OKC', 'TOR', 0.5, -3.3],
#  ['OKC', 'UTA', 0.6, -0.6],
#  ['OKC', 'MIL', 0.3, -8.7],
#  ['OKC', 'SAC', 0.7, 1.0],
#  ['OKC', 'NOP', 0.7, -6.4],
#  ['SAC', 'NYK', 0.6, 2.2],
#  ['SAC', 'ATL', 0.7, -3.7],
#  ['SAC', 'DET', 0.6, 0.8],
#  ['SAC', 'PHI', 0.4, -1.4],
#  ['SAC', 'DEN', 0.4, -2.2],
#  ['SAC', 'DAL', 0.3, -8.0],
#  ['SAC', 'CHA', 0.7, 4.9],
#  ['SAC', 'MIA', 0.4, -4.1],
#  ['SAC', 'SAS', 0.5, -5.1],
#  ['SAC', 'ORL', 0.5, 2.0],
#  ['SAC', 'MEM', 0.5, -4.3],
#  ['SAC', 'CHI', 0.6, 1.0],
#  ['SAC', 'CLE', 0.7, 1.6],
#  ['SAC', 'MIN', 0.6, -5.3],
#  ['SAC', 'HOU', 0.4, -9.8],
#  ['SAC', 'WAS', 0.6, -7.2],
#  ['SAC', 'BOS', 0.3, -4.5],
#  ['SAC', 'IND', 0.4, -1.2],
#  ['SAC', 'LAC', 0.3, -8.3],
#  ['SAC', 'GSW', 0.7, 1.6],
#  ['SAC', 'BKN', 0.5, -2.9],
#  ['SAC', 'LAL', 0.3, -5.7],
#  ['SAC', 'PHX', 0.5, -4.5],
#  ['SAC', 'POR', 0.5, -5.4],
#  ['SAC', 'TOR', 0.3, -5.0],
#  ['SAC', 'UTA', 0.4, -2.3],
#  ['SAC', 'MIL', 0.2, -10.4],
#  ['SAC', 'OKC', 0.4, -2.4],
#  ['SAC', 'NOP', 0.5, -8.1],
#  ['NOP', 'NYK', 0.7, 9.6],
#  ['NOP', 'ATL', 0.7, 3.8],
#  ['NOP', 'DET', 0.6, 8.3],
#  ['NOP', 'PHI', 0.5, 6.0],
#  ['NOP', 'DEN', 0.4, 5.3],
#  ['NOP', 'DAL', 0.4, -0.6],
#  ['NOP', 'CHA', 0.7, 12.4],
#  ['NOP', 'MIA', 0.4, 3.3],
#  ['NOP', 'SAS', 0.6, 2.3],
#  ['NOP', 'ORL', 0.5, 9.4],
#  ['NOP', 'MEM', 0.6, 3.1],
#  ['NOP', 'CHI', 0.6, 8.5],
#  ['NOP', 'CLE', 0.7, 9.0],
#  ['NOP', 'MIN', 0.6, 2.1],
#  ['NOP', 'HOU', 0.4, -2.4],
#  ['NOP', 'WAS', 0.6, 0.2],
#  ['NOP', 'BOS', 0.4, 2.9],
#  ['NOP', 'IND', 0.5, 6.2],
#  ['NOP', 'LAC', 0.3, -0.9],
#  ['NOP', 'GSW', 0.8, 9.0],
#  ['NOP', 'BKN', 0.5, 4.6],
#  ['NOP', 'LAL', 0.3, 1.7],
#  ['NOP', 'PHX', 0.5, 3.0],
#  ['NOP', 'POR', 0.6, 2.1],
#  ['NOP', 'TOR', 0.4, 2.5],
#  ['NOP', 'UTA', 0.4, 5.1],
#  ['NOP', 'MIL', 0.2, -3.0],
#  ['NOP', 'OKC', 0.4, 5.1],
#  ['NOP', 'SAC', 0.6, 6.8]]

# %%
wrong_pairs = []
for i in range(len(pairs)):
    if ((pairs[i][2] > 0.5) and (pairs[i][3] < 0)) or ((pairs[i][2] < 0.5) and (pairs[i][3] > 0)):
        wrong_pairs.append(pairs[i])
wrong_pairs.sort(key=lambda wrong_pairs : wrong_pairs[3])
wrong_pairs
# Out:
# [['ORL', 'NOP', 1.0, -11.0],
#  ['ORL', 'WAS', 1.0, -10.0],
#  ['DET', 'WAS', 1.0, -9.0],
#  ['PHI', 'HOU', 1.0, -9.0],
#  ['CHA', 'ATL', 1.0, -9.0],
#  ['CHI', 'WAS', 1.0, -9.0],
#  ['IND', 'HOU', 1.0, -9.0],
#  ['NYK', 'MIN', 1.0, -8.0],
#  ['DEN', 'HOU', 1.0, -8.0],
#  ['ORL', 'SAS', 1.0, -8.0],
#  ['ORL', 'MIN', 1.0, -8.0],
#  ['ORL', 'POR', 1.0, -8.0],
#  ['IND', 'NOP', 1.0, -8.0],
#  ['UTA', 'HOU', 1.0, -8.0],
#  ['OKC', 'HOU', 1.0, -8.0],
#  ['SAC', 'NOP', 1.0, -8.0],
#  ['NYK', 'ATL', 1.0, -7.0],
#  ['DET', 'MIN', 1.0, -7.0],
#  ['DET', 'POR', 1.0, -7.0],
#  ['PHI', 'NOP', 1.0, -7.0],
#  ['DEN', 'NOP', 1.0, -7.0],
#  ['ORL', 'MEM', 1.0, -7.0],
#  ['ORL', 'PHX', 1.0, -7.0],
#  ['CHI', 'MIN', 1.0, -7.0],
#  ['CHI', 'POR', 1.0, -7.0],
#  ['IND', 'WAS', 1.0, -7.0],
#  ['SAC', 'WAS', 1.0, -7.0],
#  ['PHI', 'WAS', 1.0, -6.0],
#  ['DEN', 'WAS', 1.0, -6.0],
#  ['MIA', 'HOU', 1.0, -6.0],
#  ['ORL', 'ATL', 1.0, -6.0],
#  ['ORL', 'BKN', 1.0, -6.0],
#  ['CLE', 'ATL', 1.0, -6.0],
#  ['BOS', 'HOU', 1.0, -6.0],
#  ['GSW', 'ATL', 1.0, -6.0],
#  ['BKN', 'NOP', 1.0, -6.0],
#  ['TOR', 'HOU', 1.0, -6.0],
#  ['UTA', 'WAS', 1.0, -6.0],
#  ['UTA', 'NOP', 1.0, -6.0],
#  ['OKC', 'NOP', 1.0, -6.0],
#  ['DET', 'ATL', 1.0, -5.0],
#  ['PHI', 'MIN', 1.0, -5.0],
#  ['PHI', 'POR', 1.0, -5.0],
#  ['MIA', 'NOP', 1.0, -5.0],
#  ['CHI', 'ATL', 1.0, -5.0],
#  ['IND', 'SAS', 1.0, -5.0],
#  ['IND', 'MIN', 1.0, -5.0],
#  ['IND', 'POR', 1.0, -5.0],
#  ['BKN', 'WAS', 1.0, -5.0],
#  ['LAL', 'HOU', 1.0, -5.0],
#  ['OKC', 'WAS', 1.0, -5.0],
#  ['SAC', 'SAS', 1.0, -5.0],
#  ['SAC', 'MIN', 1.0, -5.0],
#  ['SAC', 'POR', 1.0, -5.0],
#  ['PHI', 'SAS', 1.0, -4.0],
#  ['PHI', 'MEM', 1.0, -4.0],
#  ['PHI', 'PHX', 1.0, -4.0],
#  ['DEN', 'SAS', 1.0, -4.0],
#  ['DEN', 'MIN', 1.0, -4.0],
#  ['DEN', 'POR', 1.0, -4.0],
#  ['CHA', 'CLE', 1.0, -4.0],
#  ['CHA', 'GSW', 1.0, -4.0],
#  ['MIA', 'WAS', 1.0, -4.0],
#  ['SAS', 'NOP', 1.0, -4.0],
#  ['MEM', 'WAS', 1.0, -4.0],
#  ['MEM', 'NOP', 1.0, -4.0],
#  ['BOS', 'DAL', 1.0, -4.0],
#  ['BOS', 'LAC', 1.0, -4.0],
#  ['BOS', 'NOP', 1.0, -4.0],
#  ['IND', 'MIA', 1.0, -4.0],
#  ['IND', 'MEM', 1.0, -4.0],
#  ['IND', 'PHX', 1.0, -4.0],
#  ['PHX', 'NOP', 1.0, -4.0],
#  ['TOR', 'DAL', 1.0, -4.0],
#  ['TOR', 'LAC', 1.0, -4.0],
#  ['TOR', 'NOP', 1.0, -4.0],
#  ['UTA', 'MIN', 1.0, -4.0],
#  ['UTA', 'POR', 1.0, -4.0],
#  ['OKC', 'MIN', 1.0, -4.0],
#  ['OKC', 'POR', 1.0, -4.0],
#  ['SAC', 'ATL', 1.0, -4.0],
#  ['SAC', 'MEM', 1.0, -4.0],
#  ['PHI', 'ATL', 1.0, -3.0],
#  ['PHI', 'MIA', 1.0, -3.0],
#  ['DEN', 'MIA', 1.0, -3.0],
#  ['DEN', 'MEM', 1.0, -3.0],
#  ['DEN', 'PHX', 1.0, -3.0],
#  ['CHA', 'NYK', 1.0, -3.0],
#  ['SAS', 'WAS', 1.0, -3.0],
#  ['ORL', 'SAC', 1.0, -3.0],
#  ['MIN', 'WAS', 1.0, -3.0],
#  ['BOS', 'WAS', 1.0, -3.0],
#  ['IND', 'ATL', 1.0, -3.0],
#  ['BKN', 'SAS', 1.0, -3.0],
#  ['BKN', 'MIN', 1.0, -3.0],
#  ['BKN', 'POR', 1.0, -3.0],
#  ['LAL', 'DAL', 1.0, -3.0],
#  ['LAL', 'LAC', 1.0, -3.0],
#  ['LAL', 'NOP', 1.0, -3.0],
#  ['PHX', 'WAS', 1.0, -3.0],
#  ['POR', 'NOP', 1.0, -3.0],
#  ['TOR', 'WAS', 1.0, -3.0],
#  ['UTA', 'SAS', 1.0, -3.0],
#  ['UTA', 'MEM', 1.0, -3.0],
#  ['UTA', 'PHX', 1.0, -3.0],
#  ['OKC', 'SAS', 1.0, -3.0],
#  ['OKC', 'MEM', 1.0, -3.0],
#  ['OKC', 'PHX', 1.0, -3.0],
#  ['DET', 'SAC', 1.0, -2.0],
#  ['PHI', 'BKN', 1.0, -2.0],
#  ['PHI', 'UTA', 1.0, -2.0],
#  ['PHI', 'OKC', 1.0, -2.0],
#  ['DEN', 'ATL', 1.0, -2.0],
#  ['DAL', 'HOU', 1.0, -2.0],
#  ['MIA', 'SAS', 1.0, -2.0],
#  ['MIA', 'MIN', 1.0, -2.0],
#  ['MIA', 'POR', 1.0, -2.0],
#  ['ORL', 'DET', 1.0, -2.0],
#  ['ORL', 'CHI', 1.0, -2.0],
#  ['MEM', 'MIN', 1.0, -2.0],
#  ['MEM', 'POR', 1.0, -2.0],
#  ['CHI', 'SAC', 1.0, -2.0],
#  ['BOS', 'LAL', 1.0, -2.0],
#  ['BOS', 'POR', 1.0, -2.0],
#  ['IND', 'DEN', 1.0, -2.0],
#  ['IND', 'BKN', 1.0, -2.0],
#  ['IND', 'UTA', 1.0, -2.0],
#  ['IND', 'OKC', 1.0, -2.0],
#  ['LAC', 'HOU', 1.0, -2.0],
#  ['BKN', 'MEM', 1.0, -2.0],
#  ['BKN', 'PHX', 1.0, -2.0],
#  ['LAL', 'WAS', 1.0, -2.0],
#  ['PHX', 'POR', 1.0, -2.0],
#  ['POR', 'WAS', 1.0, -2.0],
#  ['UTA', 'ATL', 1.0, -2.0],
#  ['UTA', 'MIA', 1.0, -2.0],
#  ['OKC', 'ATL', 1.0, -2.0],
#  ['OKC', 'MIA', 1.0, -2.0],
#  ['NYK', 'CLE', 1.0, -1.0],
#  ['NYK', 'GSW', 1.0, -1.0],
#  ['PHI', 'DEN', 1.0, -1.0],
#  ['DEN', 'BKN', 1.0, -1.0],
#  ['DEN', 'UTA', 1.0, -1.0],
#  ['DEN', 'OKC', 1.0, -1.0],
#  ['DAL', 'LAC', 1.0, -1.0],
#  ['DAL', 'NOP', 1.0, -1.0],
#  ['MIA', 'MEM', 1.0, -1.0],
#  ['MIA', 'PHX', 1.0, -1.0],
#  ['SAS', 'MIN', 1.0, -1.0],
#  ['SAS', 'POR', 1.0, -1.0],
#  ['ORL', 'CLE', 1.0, -1.0],
#  ['ORL', 'GSW', 1.0, -1.0],
#  ['MEM', 'SAS', 1.0, -1.0],
#  ['MEM', 'PHX', 1.0, -1.0],
#  ['CHI', 'DET', 1.0, -1.0],
#  ['CLE', 'GSW', 1.0, -1.0],
#  ['BOS', 'SAS', 1.0, -1.0],
#  ['BOS', 'MIN', 1.0, -1.0],
#  ['BOS', 'PHX', 1.0, -1.0],
#  ['BOS', 'TOR', 1.0, -1.0],
#  ['IND', 'PHI', 1.0, -1.0],
#  ['GSW', 'CLE', 1.0, -1.0],
#  ['BKN', 'ATL', 1.0, -1.0],
#  ['PHX', 'SAS', 1.0, -1.0],
#  ['PHX', 'MIN', 1.0, -1.0],
#  ['POR', 'MIN', 1.0, -1.0],
#  ['TOR', 'SAS', 1.0, -1.0],
#  ['TOR', 'MIN', 1.0, -1.0],
#  ['TOR', 'LAL', 1.0, -1.0],
#  ['TOR', 'POR', 1.0, -1.0],
#  ['UTA', 'DEN', 1.0, -1.0],
#  ['UTA', 'BKN', 1.0, -1.0],
#  ['UTA', 'OKC', 1.0, -1.0],
#  ['OKC', 'BKN', 1.0, -1.0],
#  ['OKC', 'UTA', 1.0, -1.0],
#  ['ATL', 'DEN', 0.0, 1.0],
#  ['ATL', 'UTA', 0.0, 1.0],
#  ['ATL', 'OKC', 0.0, 1.0],
#  ['MEM', 'DEN', 0.0, 1.0],
#  ['MEM', 'UTA', 0.0, 1.0],
#  ['MEM', 'OKC', 0.0, 1.0],
#  ['MIN', 'MIA', 0.0, 1.0],
#  ['HOU', 'DAL', 0.0, 1.0],
#  ['HOU', 'LAC', 0.0, 1.0],
#  ['WAS', 'SAS', 0.0, 1.0],
#  ['WAS', 'LAL', 0.0, 1.0],
#  ['WAS', 'POR', 0.0, 1.0],
#  ['BKN', 'PHI', 0.0, 1.0],
#  ['BKN', 'IND', 0.0, 1.0],
#  ['PHX', 'OKC', 0.0, 1.0],
#  ['POR', 'MIA', 0.0, 1.0],
#  ['ATL', 'PHI', 0.0, 2.0],
#  ['ATL', 'IND', 0.0, 2.0],
#  ['ATL', 'SAC', 0.0, 2.0],
#  ['SAS', 'DEN', 0.0, 2.0],
#  ['SAS', 'UTA', 0.0, 2.0],
#  ['SAS', 'OKC', 0.0, 2.0],
#  ['MEM', 'PHI', 0.0, 2.0],
#  ['MEM', 'IND', 0.0, 2.0],
#  ['MIN', 'DEN', 0.0, 2.0],
#  ['MIN', 'BKN', 0.0, 2.0],
#  ['MIN', 'UTA', 0.0, 2.0],
#  ['MIN', 'OKC', 0.0, 2.0],
#  ['WAS', 'MIA', 0.0, 2.0],
#  ['WAS', 'MEM', 0.0, 2.0],
#  ['WAS', 'BOS', 0.0, 2.0],
#  ['WAS', 'PHX', 0.0, 2.0],
#  ['WAS', 'TOR', 0.0, 2.0],
#  ['PHX', 'PHI', 0.0, 2.0],
#  ['PHX', 'DEN', 0.0, 2.0],
#  ['PHX', 'UTA', 0.0, 2.0],
#  ['POR', 'UTA', 0.0, 2.0],
#  ['POR', 'OKC', 0.0, 2.0],
#  ['SAC', 'ORL', 0.0, 2.0],
#  ['NOP', 'LAL', 0.0, 2.0],
#  ['NOP', 'TOR', 0.0, 2.0],
#  ['SAS', 'PHI', 0.0, 3.0],
#  ['SAS', 'IND', 0.0, 3.0],
#  ['MIN', 'PHI', 0.0, 3.0],
#  ['MIN', 'IND', 0.0, 3.0],
#  ['HOU', 'LAL', 0.0, 3.0],
#  ['GSW', 'CHA', 0.0, 3.0],
#  ['PHX', 'IND', 0.0, 3.0],
#  ['POR', 'PHI', 0.0, 3.0],
#  ['POR', 'DEN', 0.0, 3.0],
#  ['NOP', 'MIA', 0.0, 3.0],
#  ['NOP', 'BOS', 0.0, 3.0],
#  ['ATL', 'DET', 0.0, 4.0],
#  ['ATL', 'CHI', 0.0, 4.0],
#  ['HOU', 'TOR', 0.0, 4.0],
#  ['WAS', 'DEN', 0.0, 4.0],
#  ['WAS', 'BKN', 0.0, 4.0],
#  ['WAS', 'UTA', 0.0, 4.0],
#  ['WAS', 'OKC', 0.0, 4.0],
#  ['POR', 'IND', 0.0, 4.0],
#  ['ATL', 'ORL', 0.0, 5.0],
#  ['HOU', 'BOS', 0.0, 5.0],
#  ['WAS', 'PHI', 0.0, 5.0],
#  ['WAS', 'IND', 0.0, 5.0],
#  ['NOP', 'DEN', 0.0, 5.0],
#  ['NOP', 'UTA', 0.0, 5.0],
#  ['NOP', 'OKC', 0.0, 5.0],
#  ['NOP', 'PHI', 0.0, 6.0],
#  ['NOP', 'IND', 0.0, 6.0],
#  ['MIN', 'ORL', 0.0, 7.0],
#  ['WAS', 'ORL', 0.0, 8.0]]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-2706f95c9a52> in <module>
# ----> 1 wrong_pairs['DAL']
#
# TypeError: list indices must be integers or slices, not str

# %%
len(pairs)
# Out:
# 870

# %%
#or ((pairs[i][2] < 0) and (pairs[i][3] > 0)):

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1979    1
# 1980    0
# 1981    1
# 1982    0
# 1983    1
# Name: W_L, Length: 1984, dtype: object

# %%
#preveri kje pride do nasprotij
#kako lahko popravimo vhodne podatke
#PCA - kaj je prevec?

#pa primerjava - z manj featureji

# %%
#Let' try the decision trees

from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor (max_depth=5)
tree_reg.fit(X,y)

mp = n.to_numpy()
X_points = m[:,5:]
y_points = n['Pts']

lasso_reg_points = Lasso(alpha=0.1)
lasso_reg_points.fit(X_points, y_points)

tree_reg_p = DecisionTreeRegressor (max_depth=5)
tree_reg_p.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
pairs_t = pairs
for game in range(len(pairs)):
    xt = (np.asarray(ntp[game][2])[1:]).reshape(1,-1)
    xp_t = (np.asarray(ntp[game][2])[2:]).reshape(1,-1)
    pairs_t[game][2] = np.round(tree_reg.predict(xt)[0], decimals=1)
    pairs_t[game][3] = np.round(tree_reg_p.predict(xp_t)[0], decimals=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-469230db628c> in <module>
#       4     xp_t = (np.asarray(ntp[game][2])[2:]).reshape(1,-1)
#       5     pairs_t[game][2] = np.round(tree_reg.predict(xt)[0], decimals=1)
# ----> 6     pairs_t[game][3] = np.round(tree_reg_p.predict(xp_t)[0], decimals=1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     428         """
#     429         check_is_fitted(self, 'tree_')
# --> 430         X = self._validate_X_predict(X, check_input)
#     431         proba = self.tree_.predict(X)
#     432         n_samples = X.shape[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     400                              "match the input. Model n_features is %s and "
#     401                              "input n_features is %s "
# --> 402                              % (self.n_features_, n_features))
#     403
#     404         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 19 and input n_features is 18

# %%
pairs_t
# Out:
# [['NYK', 'ATL', 1.0, -6.5],
#  ['NYK', 'DET', 0.0, -2.0],
#  ['NYK', 'PHI', 0.0, -4.3],
#  ['NYK', 'DEN', 0.0, -5.0],
#  ['NYK', 'DAL', 0.0, -10.9],
#  ['NYK', 'CHA', 1.0, 2.1],
#  ['NYK', 'MIA', 0.0, -7.0],
#  ['NYK', 'SAS', 0.0, -8.0],
#  ['NYK', 'ORL', 0.0, -0.9],
#  ['NYK', 'MEM', 0.0, -7.2],
#  ['NYK', 'CHI', 0.0, -1.8],
#  ['NYK', 'CLE', 1.0, -1.3],
#  ['NYK', 'MIN', 0.0, -8.2],
#  ['NYK', 'HOU', 0.0, -12.7],
#  ['NYK', 'WAS', 0.0, -10.1],
#  ['NYK', 'BOS', 0.0, -7.4],
#  ['NYK', 'IND', 0.0, -4.1],
#  ['NYK', 'LAC', 0.0, -11.2],
#  ['NYK', 'GSW', 1.0, -1.3],
#  ['NYK', 'BKN', 0.0, -5.8],
#  ['NYK', 'LAL', 0.0, -8.6],
#  ['NYK', 'PHX', 0.0, -7.3],
#  ['NYK', 'POR', 0.0, -8.3],
#  ['NYK', 'TOR', 0.0, -7.8],
#  ['NYK', 'UTA', 0.0, -5.2],
#  ['NYK', 'MIL', 0.0, -13.3],
#  ['NYK', 'OKC', 0.0, -5.2],
#  ['NYK', 'SAC', 0.0, -3.5],
#  ['NYK', 'NOP', 0.0, -11.0],
#  ['ATL', 'NYK', 0.0, 5.2],
#  ['ATL', 'DET', 0.0, 3.8],
#  ['ATL', 'PHI', 0.0, 1.6],
#  ['ATL', 'DEN', 0.0, 0.8],
#  ['ATL', 'DAL', 0.0, -5.0],
#  ['ATL', 'CHA', 0.0, 7.9],
#  ['ATL', 'MIA', 0.0, -1.1],
#  ['ATL', 'SAS', 0.0, -2.1],
#  ['ATL', 'ORL', 0.0, 5.0],
#  ['ATL', 'MEM', 0.0, -1.3],
#  ['ATL', 'CHI', 0.0, 4.0],
#  ['ATL', 'CLE', 1.0, 4.6],
#  ['ATL', 'MIN', 0.0, -2.3],
#  ['ATL', 'HOU', 0.0, -6.8],
#  ['ATL', 'WAS', 0.0, -4.2],
#  ['ATL', 'BOS', 0.0, -1.5],
#  ['ATL', 'IND', 0.0, 1.8],
#  ['ATL', 'LAC', 0.0, -5.3],
#  ['ATL', 'GSW', 1.0, 4.6],
#  ['ATL', 'BKN', 0.0, 0.1],
#  ['ATL', 'LAL', 0.0, -2.7],
#  ['ATL', 'PHX', 0.0, -1.5],
#  ['ATL', 'POR', 0.0, -2.4],
#  ['ATL', 'TOR', 0.0, -2.0],
#  ['ATL', 'UTA', 0.0, 0.7],
#  ['ATL', 'MIL', 0.0, -7.4],
#  ['ATL', 'OKC', 0.0, 0.6],
#  ['ATL', 'SAC', 0.0, 2.3],
#  ['ATL', 'NOP', 0.0, -5.1],
#  ['DET', 'NYK', 1.0, 0.7],
#  ['DET', 'ATL', 1.0, -5.2],
#  ['DET', 'PHI', 0.0, -2.9],
#  ['DET', 'DEN', 0.0, -3.7],
#  ['DET', 'DAL', 0.0, -9.5],
#  ['DET', 'CHA', 1.0, 3.4],
#  ['DET', 'MIA', 0.0, -5.6],
#  ['DET', 'SAS', 0.0, -6.6],
#  ['DET', 'ORL', 0.0, 0.5],
#  ['DET', 'MEM', 0.0, -5.8],
#  ['DET', 'CHI', 0.0, -0.5],
#  ['DET', 'CLE', 1.0, 0.1],
#  ['DET', 'MIN', 1.0, -6.8],
#  ['DET', 'HOU', 0.0, -11.3],
#  ['DET', 'WAS', 1.0, -8.7],
#  ['DET', 'BOS', 0.0, -6.0],
#  ['DET', 'IND', 0.0, -2.7],
#  ['DET', 'LAC', 0.0, -9.8],
#  ['DET', 'GSW', 1.0, 0.1],
#  ['DET', 'BKN', 0.0, -4.4],
#  ['DET', 'LAL', 0.0, -7.2],
#  ['DET', 'PHX', 0.0, -6.0],
#  ['DET', 'POR', 0.0, -6.9],
#  ['DET', 'TOR', 0.0, -6.5],
#  ['DET', 'UTA', 0.0, -3.8],
#  ['DET', 'MIL', 0.0, -11.9],
#  ['DET', 'OKC', 0.0, -3.9],
#  ['DET', 'SAC', 0.0, -2.2],
#  ['DET', 'NOP', 0.0, -9.6],
#  ['PHI', 'NYK', 1.0, 3.0],
#  ['PHI', 'ATL', 1.0, -2.9],
#  ['PHI', 'DET', 1.0, 1.6],
#  ['PHI', 'DEN', 0.0, -1.4],
#  ['PHI', 'DAL', 0.0, -7.3],
#  ['PHI', 'CHA', 1.0, 5.7],
#  ['PHI', 'MIA', 0.0, -3.4],
#  ['PHI', 'SAS', 1.0, -4.4],
#  ['PHI', 'ORL', 1.0, 2.7],
#  ['PHI', 'MEM', 1.0, -3.5],
#  ['PHI', 'CHI', 1.0, 1.8],
#  ['PHI', 'CLE', 1.0, 2.3],
#  ['PHI', 'MIN', 1.0, -4.6],
#  ['PHI', 'HOU', 0.0, -9.1],
#  ['PHI', 'WAS', 1.0, -6.5],
#  ['PHI', 'BOS', 0.0, -3.8],
#  ['PHI', 'IND', 1.0, -0.5],
#  ['PHI', 'LAC', 0.0, -7.6],
#  ['PHI', 'GSW', 1.0, 2.3],
#  ['PHI', 'BKN', 1.0, -2.1],
#  ['PHI', 'LAL', 0.0, -5.0],
#  ['PHI', 'PHX', 1.0, -3.7],
#  ['PHI', 'POR', 1.0, -4.6],
#  ['PHI', 'TOR', 0.0, -4.2],
#  ['PHI', 'UTA', 0.0, -1.6],
#  ['PHI', 'MIL', 0.0, -9.7],
#  ['PHI', 'OKC', 1.0, -1.6],
#  ['PHI', 'SAC', 1.0, 0.1],
#  ['PHI', 'NOP', 1.0, -7.4],
#  ['DEN', 'NYK', 1.0, 3.7],
#  ['DEN', 'ATL', 1.0, -2.2],
#  ['DEN', 'DET', 1.0, 2.3],
#  ['DEN', 'PHI', 1.0, 0.1],
#  ['DEN', 'DAL', 0.0, -6.5],
#  ['DEN', 'CHA', 1.0, 6.4],
#  ['DEN', 'MIA', 0.0, -2.6],
#  ['DEN', 'SAS', 1.0, -3.6],
#  ['DEN', 'ORL', 1.0, 3.5],
#  ['DEN', 'MEM', 1.0, -2.8],
#  ['DEN', 'CHI', 1.0, 2.5],
#  ['DEN', 'CLE', 1.0, 3.1],
#  ['DEN', 'MIN', 1.0, -3.8],
#  ['DEN', 'HOU', 0.0, -8.3],
#  ['DEN', 'WAS', 1.0, -5.7],
#  ['DEN', 'BOS', 0.0, -3.0],
#  ['DEN', 'IND', 1.0, 0.3],
#  ['DEN', 'LAC', 0.0, -6.8],
#  ['DEN', 'GSW', 1.0, 3.1],
#  ['DEN', 'BKN', 1.0, -1.4],
#  ['DEN', 'LAL', 0.0, -4.2],
#  ['DEN', 'PHX', 1.0, -3.0],
#  ['DEN', 'POR', 1.0, -3.9],
#  ['DEN', 'TOR', 0.0, -3.5],
#  ['DEN', 'UTA', 0.0, -0.8],
#  ['DEN', 'MIL', 0.0, -8.9],
#  ['DEN', 'OKC', 1.0, -0.9],
#  ['DEN', 'SAC', 1.0, 0.8],
#  ['DEN', 'NOP', 1.0, -6.6],
#  ['DAL', 'NYK', 1.0, 9.6],
#  ['DAL', 'ATL', 1.0, 3.7],
#  ['DAL', 'DET', 1.0, 8.2],
#  ['DAL', 'PHI', 1.0, 6.0],
#  ['DAL', 'DEN', 1.0, 5.2],
#  ['DAL', 'CHA', 1.0, 12.3],
#  ['DAL', 'MIA', 1.0, 3.3],
#  ['DAL', 'SAS', 1.0, 2.3],
#  ['DAL', 'ORL', 1.0, 9.4],
#  ['DAL', 'MEM', 1.0, 3.1],
#  ['DAL', 'CHI', 1.0, 8.4],
#  ['DAL', 'CLE', 1.0, 9.0],
#  ['DAL', 'MIN', 1.0, 2.1],
#  ['DAL', 'HOU', 1.0, -2.4],
#  ['DAL', 'WAS', 1.0, 0.2],
#  ['DAL', 'BOS', 1.0, 2.9],
#  ['DAL', 'IND', 1.0, 6.2],
#  ['DAL', 'LAC', 0.0, -0.9],
#  ['DAL', 'GSW', 1.0, 9.0],
#  ['DAL', 'BKN', 1.0, 4.5],
#  ['DAL', 'LAL', 0.0, 1.7],
#  ['DAL', 'PHX', 1.0, 2.9],
#  ['DAL', 'POR', 1.0, 2.0],
#  ['DAL', 'TOR', 0.0, 2.4],
#  ['DAL', 'UTA', 1.0, 5.1],
#  ['DAL', 'MIL', 0.0, -3.1],
#  ['DAL', 'OKC', 1.0, 5.0],
#  ['DAL', 'SAC', 1.0, 6.7],
#  ['DAL', 'NOP', 1.0, -0.7],
#  ['CHA', 'NYK', 0.0, -3.4],
#  ['CHA', 'ATL', 1.0, -9.3],
#  ['CHA', 'DET', 0.0, -4.7],
#  ['CHA', 'PHI', 0.0, -7.0],
#  ['CHA', 'DEN', 0.0, -7.8],
#  ['CHA', 'DAL', 0.0, -13.6],
#  ['CHA', 'MIA', 0.0, -9.7],
#  ['CHA', 'SAS', 0.0, -10.7],
#  ['CHA', 'ORL', 0.0, -3.6],
#  ['CHA', 'MEM', 0.0, -9.9],
#  ['CHA', 'CHI', 0.0, -4.6],
#  ['CHA', 'CLE', 1.0, -4.0],
#  ['CHA', 'MIN', 0.0, -10.9],
#  ['CHA', 'HOU', 0.0, -15.4],
#  ['CHA', 'WAS', 0.0, -12.8],
#  ['CHA', 'BOS', 0.0, -10.1],
#  ['CHA', 'IND', 0.0, -6.8],
#  ['CHA', 'LAC', 0.0, -13.9],
#  ['CHA', 'GSW', 1.0, -4.0],
#  ['CHA', 'BKN', 0.0, -8.5],
#  ['CHA', 'LAL', 0.0, -11.3],
#  ['CHA', 'PHX', 0.0, -10.1],
#  ['CHA', 'POR', 0.0, -11.0],
#  ['CHA', 'TOR', 0.0, -10.6],
#  ['CHA', 'UTA', 0.0, -7.9],
#  ['CHA', 'MIL', 0.0, -16.0],
#  ['CHA', 'OKC', 0.0, -8.0],
#  ['CHA', 'SAC', 0.0, -6.2],
#  ['CHA', 'NOP', 0.0, -13.7],
#  ['MIA', 'NYK', 1.0, 5.7],
#  ['MIA', 'ATL', 1.0, -0.2],
#  ['MIA', 'DET', 1.0, 4.3],
#  ['MIA', 'PHI', 1.0, 2.1],
#  ['MIA', 'DEN', 1.0, 1.3],
#  ['MIA', 'DAL', 0.0, -4.6],
#  ['MIA', 'CHA', 1.0, 8.4],
#  ['MIA', 'SAS', 1.0, -1.7],
#  ['MIA', 'ORL', 1.0, 5.4],
#  ['MIA', 'MEM', 1.0, -0.8],
#  ['MIA', 'CHI', 1.0, 4.5],
#  ['MIA', 'CLE', 1.0, 5.0],
#  ['MIA', 'MIN', 1.0, -1.8],
#  ['MIA', 'HOU', 0.0, -6.4],
#  ['MIA', 'WAS', 1.0, -3.7],
#  ['MIA', 'BOS', 0.0, -1.1],
#  ['MIA', 'IND', 1.0, 2.2],
#  ['MIA', 'LAC', 0.0, -4.9],
#  ['MIA', 'GSW', 1.0, 5.0],
#  ['MIA', 'BKN', 1.0, 0.6],
#  ['MIA', 'LAL', 0.0, -2.2],
#  ['MIA', 'PHX', 1.0, -1.0],
#  ['MIA', 'POR', 1.0, -1.9],
#  ['MIA', 'TOR', 0.0, -1.5],
#  ['MIA', 'UTA', 1.0, 1.1],
#  ['MIA', 'MIL', 0.0, -7.0],
#  ['MIA', 'OKC', 1.0, 1.1],
#  ['MIA', 'SAC', 1.0, 2.8],
#  ['MIA', 'NOP', 1.0, -4.6],
#  ['SAS', 'NYK', 1.0, 6.7],
#  ['SAS', 'ATL', 1.0, 0.8],
#  ['SAS', 'DET', 1.0, 5.3],
#  ['SAS', 'PHI', 0.0, 3.0],
#  ['SAS', 'DEN', 0.0, 2.3],
#  ['SAS', 'DAL', 0.0, -3.6],
#  ['SAS', 'CHA', 1.0, 9.4],
#  ['SAS', 'MIA', 0.0, 0.3],
#  ['SAS', 'ORL', 0.0, 6.4],
#  ['SAS', 'MEM', 0.0, 0.2],
#  ['SAS', 'CHI', 1.0, 5.5],
#  ['SAS', 'CLE', 1.0, 6.0],
#  ['SAS', 'MIN', 1.0, -0.8],
#  ['SAS', 'HOU', 0.0, -5.4],
#  ['SAS', 'WAS', 1.0, -2.7],
#  ['SAS', 'BOS', 0.0, -0.1],
#  ['SAS', 'IND', 0.0, 3.2],
#  ['SAS', 'LAC', 0.0, -3.9],
#  ['SAS', 'GSW', 1.0, 6.0],
#  ['SAS', 'BKN', 0.0, 1.6],
#  ['SAS', 'LAL', 0.0, -1.2],
#  ['SAS', 'PHX', 0.0, -0.0],
#  ['SAS', 'POR', 0.0, -0.9],
#  ['SAS', 'TOR', 0.0, -0.5],
#  ['SAS', 'UTA', 0.0, 2.1],
#  ['SAS', 'MIL', 0.0, -6.0],
#  ['SAS', 'OKC', 0.0, 2.1],
#  ['SAS', 'SAC', 1.0, 3.8],
#  ['SAS', 'NOP', 0.0, -3.6],
#  ['ORL', 'NYK', 1.0, -0.4],
#  ['ORL', 'ATL', 1.0, -6.3],
#  ['ORL', 'DET', 1.0, -1.8],
#  ['ORL', 'PHI', 0.0, -4.0],
#  ['ORL', 'DEN', 0.0, -4.8],
#  ['ORL', 'DAL', 0.0, -10.7],
#  ['ORL', 'CHA', 1.0, 2.3],
#  ['ORL', 'MIA', 0.0, -6.7],
#  ['ORL', 'SAS', 1.0, -7.7],
#  ['ORL', 'MEM', 1.0, -6.9],
#  ['ORL', 'CHI', 1.0, -1.6],
#  ['ORL', 'CLE', 1.0, -1.0],
#  ['ORL', 'MIN', 1.0, -7.9],
#  ['ORL', 'HOU', 0.0, -12.5],
#  ['ORL', 'WAS', 1.0, -9.8],
#  ['ORL', 'BOS', 0.0, -7.1],
#  ['ORL', 'IND', 0.0, -3.8],
#  ['ORL', 'LAC', 0.0, -10.9],
#  ['ORL', 'GSW', 1.0, -1.0],
#  ['ORL', 'BKN', 0.0, -5.5],
#  ['ORL', 'LAL', 0.0, -8.3],
#  ['ORL', 'PHX', 1.0, -7.1],
#  ['ORL', 'POR', 1.0, -8.0],
#  ['ORL', 'TOR', 0.0, -7.6],
#  ['ORL', 'UTA', 0.0, -4.9],
#  ['ORL', 'MIL', 0.0, -13.1],
#  ['ORL', 'OKC', 0.0, -5.0],
#  ['ORL', 'SAC', 1.0, -3.3],
#  ['ORL', 'NOP', 1.0, -10.7],
#  ['MEM', 'NYK', 1.0, 5.8],
#  ['MEM', 'ATL', 1.0, -0.0],
#  ['MEM', 'DET', 1.0, 4.5],
#  ['MEM', 'PHI', 0.0, 2.2],
#  ['MEM', 'DEN', 0.0, 1.5],
#  ['MEM', 'DAL', 0.0, -4.4],
#  ['MEM', 'CHA', 1.0, 8.6],
#  ['MEM', 'MIA', 0.0, -0.5],
#  ['MEM', 'SAS', 1.0, -1.5],
#  ['MEM', 'ORL', 0.0, 5.6],
#  ['MEM', 'CHI', 1.0, 4.7],
#  ['MEM', 'CLE', 1.0, 5.2],
#  ['MEM', 'MIN', 1.0, -1.7],
#  ['MEM', 'HOU', 0.0, -6.2],
#  ['MEM', 'WAS', 1.0, -3.6],
#  ['MEM', 'BOS', 0.0, -0.9],
#  ['MEM', 'IND', 0.0, 2.4],
#  ['MEM', 'LAC', 0.0, -4.7],
#  ['MEM', 'GSW', 1.0, 5.2],
#  ['MEM', 'BKN', 0.0, 0.8],
#  ['MEM', 'LAL', 0.0, -2.1],
#  ['MEM', 'PHX', 0.0, -0.8],
#  ['MEM', 'POR', 1.0, -1.8],
#  ['MEM', 'TOR', 0.0, -1.3],
#  ['MEM', 'UTA', 0.0, 1.3],
#  ['MEM', 'MIL', 0.0, -6.8],
#  ['MEM', 'OKC', 0.0, 1.3],
#  ['MEM', 'SAC', 1.0, 3.0],
#  ['MEM', 'NOP', 0.0, -4.5],
#  ['CHI', 'NYK', 1.0, 0.5],
#  ['CHI', 'ATL', 1.0, -5.4],
#  ['CHI', 'DET', 1.0, -0.8],
#  ['CHI', 'PHI', 0.0, -3.1],
#  ['CHI', 'DEN', 0.0, -3.9],
#  ['CHI', 'DAL', 0.0, -9.7],
#  ['CHI', 'CHA', 1.0, 3.2],
#  ['CHI', 'MIA', 0.0, -5.8],
#  ['CHI', 'SAS', 0.0, -6.8],
#  ['CHI', 'ORL', 0.0, 0.3],
#  ['CHI', 'MEM', 0.0, -6.0],
#  ['CHI', 'CLE', 1.0, -0.1],
#  ['CHI', 'MIN', 1.0, -7.0],
#  ['CHI', 'HOU', 0.0, -11.5],
#  ['CHI', 'WAS', 1.0, -8.9],
#  ['CHI', 'BOS', 0.0, -6.2],
#  ['CHI', 'IND', 0.0, -2.9],
#  ['CHI', 'LAC', 0.0, -10.0],
#  ['CHI', 'GSW', 1.0, -0.1],
#  ['CHI', 'BKN', 0.0, -4.6],
#  ['CHI', 'LAL', 0.0, -7.4],
#  ['CHI', 'PHX', 0.0, -6.2],
#  ['CHI', 'POR', 0.0, -7.1],
#  ['CHI', 'TOR', 0.0, -6.7],
#  ['CHI', 'UTA', 0.0, -4.0],
#  ['CHI', 'MIL', 0.0, -12.1],
#  ['CHI', 'OKC', 0.0, -4.1],
#  ['CHI', 'SAC', 0.0, -2.3],
#  ['CHI', 'NOP', 0.0, -9.8],
#  ['CLE', 'NYK', 0.0, -0.0],
#  ['CLE', 'ATL', 0.0, -5.9],
#  ['CLE', 'DET', 0.0, -1.4],
#  ['CLE', 'PHI', 0.0, -3.7],
#  ['CLE', 'DEN', 0.0, -4.4],
#  ['CLE', 'DAL', 0.0, -10.3],
#  ['CLE', 'CHA', 0.0, 2.7],
#  ['CLE', 'MIA', 0.0, -6.4],
#  ['CLE', 'SAS', 0.0, -7.4],
#  ['CLE', 'ORL', 0.0, -0.3],
#  ['CLE', 'MEM', 0.0, -6.5],
#  ['CLE', 'CHI', 0.0, -1.2],
#  ['CLE', 'MIN', 0.0, -7.5],
#  ['CLE', 'HOU', 0.0, -12.1],
#  ['CLE', 'WAS', 0.0, -9.4],
#  ['CLE', 'BOS', 0.0, -6.8],
#  ['CLE', 'IND', 0.0, -3.5],
#  ['CLE', 'LAC', 0.0, -10.6],
#  ['CLE', 'GSW', 1.0, -0.7],
#  ['CLE', 'BKN', 0.0, -5.1],
#  ['CLE', 'LAL', 0.0, -7.9],
#  ['CLE', 'PHX', 0.0, -6.7],
#  ['CLE', 'POR', 0.0, -7.6],
#  ['CLE', 'TOR', 0.0, -7.2],
#  ['CLE', 'UTA', 0.0, -4.6],
#  ['CLE', 'MIL', 0.0, -12.7],
#  ['CLE', 'OKC', 0.0, -4.6],
#  ['CLE', 'SAC', 0.0, -2.9],
#  ['CLE', 'NOP', 0.0, -10.3],
#  ['MIN', 'NYK', 1.0, 6.9],
#  ['MIN', 'ATL', 1.0, 1.0],
#  ['MIN', 'DET', 0.0, 5.5],
#  ['MIN', 'PHI', 0.0, 3.2],
#  ['MIN', 'DEN', 0.0, 2.5],
#  ['MIN', 'DAL', 0.0, -3.4],
#  ['MIN', 'CHA', 1.0, 9.6],
#  ['MIN', 'MIA', 0.0, 0.5],
#  ['MIN', 'SAS', 0.0, -0.5],
#  ['MIN', 'ORL', 0.0, 6.6],
#  ['MIN', 'MEM', 0.0, 0.3],
#  ['MIN', 'CHI', 0.0, 5.7],
#  ['MIN', 'CLE', 1.0, 6.2],
#  ['MIN', 'HOU', 0.0, -5.2],
#  ['MIN', 'WAS', 0.0, -2.6],
#  ['MIN', 'BOS', 0.0, 0.1],
#  ['MIN', 'IND', 0.0, 3.4],
#  ['MIN', 'LAC', 0.0, -3.7],
#  ['MIN', 'GSW', 1.0, 6.2],
#  ['MIN', 'BKN', 0.0, 1.8],
#  ['MIN', 'LAL', 0.0, -1.1],
#  ['MIN', 'PHX', 0.0, 0.2],
#  ['MIN', 'POR', 0.0, -0.7],
#  ['MIN', 'TOR', 0.0, -0.3],
#  ['MIN', 'UTA', 0.0, 2.3],
#  ['MIN', 'MIL', 0.0, -5.8],
#  ['MIN', 'OKC', 0.0, 2.3],
#  ['MIN', 'SAC', 0.0, 4.0],
#  ['MIN', 'NOP', 0.0, -3.5],
#  ['HOU', 'NYK', 1.0, 11.4],
#  ['HOU', 'ATL', 1.0, 5.5],
#  ['HOU', 'DET', 1.0, 10.0],
#  ['HOU', 'PHI', 1.0, 7.8],
#  ['HOU', 'DEN', 1.0, 7.0],
#  ['HOU', 'DAL', 0.0, 1.1],
#  ['HOU', 'CHA', 1.0, 14.1],
#  ['HOU', 'MIA', 1.0, 5.1],
#  ['HOU', 'SAS', 1.0, 4.1],
#  ['HOU', 'ORL', 1.0, 11.1],
#  ['HOU', 'MEM', 1.0, 4.9],
#  ['HOU', 'CHI', 1.0, 10.2],
#  ['HOU', 'CLE', 1.0, 10.8],
#  ['HOU', 'MIN', 1.0, 3.9],
#  ['HOU', 'WAS', 1.0, 2.0],
#  ['HOU', 'BOS', 0.0, 4.6],
#  ['HOU', 'IND', 1.0, 8.0],
#  ['HOU', 'LAC', 0.0, 0.8],
#  ['HOU', 'GSW', 1.0, 10.8],
#  ['HOU', 'BKN', 1.0, 6.3],
#  ['HOU', 'LAL', 0.0, 3.5],
#  ['HOU', 'PHX', 1.0, 4.7],
#  ['HOU', 'POR', 1.0, 3.8],
#  ['HOU', 'TOR', 0.0, 4.2],
#  ['HOU', 'UTA', 1.0, 6.9],
#  ['HOU', 'MIL', 0.0, -1.3],
#  ['HOU', 'OKC', 1.0, 6.8],
#  ['HOU', 'SAC', 1.0, 8.5],
#  ['HOU', 'NOP', 1.0, 1.1],
#  ['WAS', 'NYK', 1.0, 8.7],
#  ['WAS', 'ATL', 1.0, 2.9],
#  ['WAS', 'DET', 0.0, 7.4],
#  ['WAS', 'PHI', 0.0, 5.1],
#  ['WAS', 'DEN', 0.0, 4.4],
#  ['WAS', 'DAL', 0.0, -1.5],
#  ['WAS', 'CHA', 1.0, 11.5],
#  ['WAS', 'MIA', 0.0, 2.4],
#  ['WAS', 'SAS', 0.0, 1.4],
#  ['WAS', 'ORL', 0.0, 8.5],
#  ['WAS', 'MEM', 0.0, 2.2],
#  ['WAS', 'CHI', 0.0, 7.6],
#  ['WAS', 'CLE', 1.0, 8.1],
#  ['WAS', 'MIN', 1.0, 1.2],
#  ['WAS', 'HOU', 0.0, -3.3],
#  ['WAS', 'BOS', 0.0, 2.0],
#  ['WAS', 'IND', 0.0, 5.3],
#  ['WAS', 'LAC', 0.0, -1.8],
#  ['WAS', 'GSW', 1.0, 8.1],
#  ['WAS', 'BKN', 0.0, 3.7],
#  ['WAS', 'LAL', 0.0, 0.8],
#  ['WAS', 'PHX', 0.0, 2.1],
#  ['WAS', 'POR', 0.0, 1.2],
#  ['WAS', 'TOR', 0.0, 1.6],
#  ['WAS', 'UTA', 0.0, 4.2],
#  ['WAS', 'MIL', 0.0, -3.9],
#  ['WAS', 'OKC', 0.0, 4.2],
#  ['WAS', 'SAC', 0.0, 5.9],
#  ['WAS', 'NOP', 0.0, -1.6],
#  ['BOS', 'NYK', 1.0, 6.1],
#  ['BOS', 'ATL', 1.0, 0.2],
#  ['BOS', 'DET', 1.0, 4.7],
#  ['BOS', 'PHI', 1.0, 2.5],
#  ['BOS', 'DEN', 1.0, 1.7],
#  ['BOS', 'DAL', 0.0, -4.2],
#  ['BOS', 'CHA', 1.0, 8.8],
#  ['BOS', 'MIA', 1.0, -0.2],
#  ['BOS', 'SAS', 1.0, -1.2],
#  ['BOS', 'ORL', 1.0, 5.8],
#  ['BOS', 'MEM', 1.0, -0.4],
#  ['BOS', 'CHI', 1.0, 4.9],
#  ['BOS', 'CLE', 1.0, 5.5],
#  ['BOS', 'MIN', 1.0, -1.4],
#  ['BOS', 'HOU', 1.0, -6.0],
#  ['BOS', 'WAS', 1.0, -3.3],
#  ['BOS', 'IND', 1.0, 2.7],
#  ['BOS', 'LAC', 0.0, -4.5],
#  ['BOS', 'GSW', 1.0, 5.5],
#  ['BOS', 'BKN', 1.0, 1.0],
#  ['BOS', 'LAL', 0.0, -1.8],
#  ['BOS', 'PHX', 1.0, -0.6],
#  ['BOS', 'POR', 1.0, -1.5],
#  ['BOS', 'TOR', 0.0, -1.1],
#  ['BOS', 'UTA', 1.0, 1.6],
#  ['BOS', 'MIL', 0.0, -6.6],
#  ['BOS', 'OKC', 1.0, 1.5],
#  ['BOS', 'SAC', 1.0, 3.2],
#  ['BOS', 'NOP', 1.0, -4.2],
#  ['IND', 'NYK', 1.0, 2.8],
#  ['IND', 'ATL', 1.0, -3.1],
#  ['IND', 'DET', 1.0, 1.4],
#  ['IND', 'PHI', 0.0, -0.8],
#  ['IND', 'DEN', 0.0, -1.6],
#  ['IND', 'DAL', 0.0, -7.5],
#  ['IND', 'CHA', 1.0, 5.5],
#  ['IND', 'MIA', 0.0, -3.5],
#  ['IND', 'SAS', 1.0, -4.5],
#  ['IND', 'ORL', 1.0, 2.5],
#  ['IND', 'MEM', 1.0, -3.7],
#  ['IND', 'CHI', 1.0, 1.6],
#  ['IND', 'CLE', 1.0, 2.2],
#  ['IND', 'MIN', 1.0, -4.7],
#  ['IND', 'HOU', 0.0, -9.3],
#  ['IND', 'WAS', 1.0, -6.6],
#  ['IND', 'BOS', 0.0, -4.0],
#  ['IND', 'LAC', 0.0, -7.8],
#  ['IND', 'GSW', 1.0, 2.1],
#  ['IND', 'BKN', 1.0, -2.3],
#  ['IND', 'LAL', 0.0, -5.1],
#  ['IND', 'PHX', 1.0, -3.9],
#  ['IND', 'POR', 1.0, -4.8],
#  ['IND', 'TOR', 0.0, -4.4],
#  ['IND', 'UTA', 0.0, -1.8],
#  ['IND', 'MIL', 0.0, -9.9],
#  ['IND', 'OKC', 0.0, -1.8],
#  ['IND', 'SAC', 1.0, -0.1],
#  ['IND', 'NOP', 1.0, -7.5],
#  ['LAC', 'NYK', 1.0, 9.9],
#  ['LAC', 'ATL', 1.0, 4.0],
#  ['LAC', 'DET', 1.0, 8.5],
#  ['LAC', 'PHI', 1.0, 6.3],
#  ['LAC', 'DEN', 1.0, 5.5],
#  ['LAC', 'DAL', 1.0, -0.4],
#  ['LAC', 'CHA', 1.0, 12.6],
#  ['LAC', 'MIA', 1.0, 3.6],
#  ['LAC', 'SAS', 1.0, 2.6],
#  ['LAC', 'ORL', 1.0, 9.6],
#  ['LAC', 'MEM', 1.0, 3.4],
#  ['LAC', 'CHI', 1.0, 8.7],
#  ['LAC', 'CLE', 1.0, 9.3],
#  ['LAC', 'MIN', 1.0, 2.4],
#  ['LAC', 'HOU', 1.0, -2.2],
#  ['LAC', 'WAS', 1.0, 0.5],
#  ['LAC', 'BOS', 1.0, 3.1],
#  ['LAC', 'IND', 1.0, 6.5],
#  ['LAC', 'GSW', 1.0, 9.3],
#  ['LAC', 'BKN', 1.0, 4.8],
#  ['LAC', 'LAL', 0.0, 2.0],
#  ['LAC', 'PHX', 1.0, 3.2],
#  ['LAC', 'POR', 1.0, 2.3],
#  ['LAC', 'TOR', 1.0, 2.7],
#  ['LAC', 'UTA', 1.0, 5.4],
#  ['LAC', 'MIL', 0.0, -2.8],
#  ['LAC', 'OKC', 1.0, 5.3],
#  ['LAC', 'SAC', 1.0, 7.0],
#  ['LAC', 'NOP', 1.0, -0.4],
#  ['GSW', 'NYK', 0.0, -0.0],
#  ['GSW', 'ATL', 0.0, -5.9],
#  ['GSW', 'DET', 0.0, -1.4],
#  ['GSW', 'PHI', 0.0, -3.6],
#  ['GSW', 'DEN', 0.0, -4.4],
#  ['GSW', 'DAL', 0.0, -10.3],
#  ['GSW', 'CHA', 0.0, 2.7],
#  ['GSW', 'MIA', 0.0, -6.4],
#  ['GSW', 'SAS', 0.0, -7.3],
#  ['GSW', 'ORL', 0.0, -0.3],
#  ['GSW', 'MEM', 0.0, -6.5],
#  ['GSW', 'CHI', 0.0, -1.2],
#  ['GSW', 'CLE', 0.0, -0.6],
#  ['GSW', 'MIN', 0.0, -7.5],
#  ['GSW', 'HOU', 0.0, -12.1],
#  ['GSW', 'WAS', 0.0, -9.4],
#  ['GSW', 'BOS', 0.0, -6.8],
#  ['GSW', 'IND', 0.0, -3.5],
#  ['GSW', 'LAC', 0.0, -10.6],
#  ['GSW', 'BKN', 0.0, -5.1],
#  ['GSW', 'LAL', 0.0, -7.9],
#  ['GSW', 'PHX', 0.0, -6.7],
#  ['GSW', 'POR', 0.0, -7.6],
#  ['GSW', 'TOR', 0.0, -7.2],
#  ['GSW', 'UTA', 0.0, -4.6],
#  ['GSW', 'MIL', 0.0, -12.7],
#  ['GSW', 'OKC', 0.0, -4.6],
#  ['GSW', 'SAC', 0.0, -2.9],
#  ['GSW', 'NOP', 0.0, -10.3],
#  ['BKN', 'NYK', 1.0, 4.4],
#  ['BKN', 'ATL', 1.0, -1.4],
#  ['BKN', 'DET', 1.0, 3.1],
#  ['BKN', 'PHI', 0.0, 0.8],
#  ['BKN', 'DEN', 0.0, 0.1],
#  ['BKN', 'DAL', 0.0, -5.8],
#  ['BKN', 'CHA', 1.0, 7.1],
#  ['BKN', 'MIA', 0.0, -1.9],
#  ['BKN', 'SAS', 1.0, -2.9],
#  ['BKN', 'ORL', 1.0, 4.2],
#  ['BKN', 'MEM', 1.0, -2.1],
#  ['BKN', 'CHI', 1.0, 3.2],
#  ['BKN', 'CLE', 1.0, 3.8],
#  ['BKN', 'MIN', 1.0, -3.1],
#  ['BKN', 'HOU', 0.0, -7.6],
#  ['BKN', 'WAS', 1.0, -5.0],
#  ['BKN', 'BOS', 0.0, -2.3],
#  ['BKN', 'IND', 0.0, 1.0],
#  ['BKN', 'LAC', 0.0, -6.1],
#  ['BKN', 'GSW', 1.0, 3.8],
#  ['BKN', 'LAL', 0.0, -3.5],
#  ['BKN', 'PHX', 1.0, -2.3],
#  ['BKN', 'POR', 1.0, -3.2],
#  ['BKN', 'TOR', 0.0, -2.8],
#  ['BKN', 'UTA', 0.0, -0.1],
#  ['BKN', 'MIL', 0.0, -8.2],
#  ['BKN', 'OKC', 0.0, -0.1],
#  ['BKN', 'SAC', 1.0, 1.6],
#  ['BKN', 'NOP', 1.0, -5.9],
#  ['LAL', 'NYK', 1.0, 7.2],
#  ['LAL', 'ATL', 1.0, 1.4],
#  ['LAL', 'DET', 1.0, 5.9],
#  ['LAL', 'PHI', 1.0, 3.6],
#  ['LAL', 'DEN', 1.0, 2.9],
#  ['LAL', 'DAL', 1.0, -3.0],
#  ['LAL', 'CHA', 1.0, 10.0],
#  ['LAL', 'MIA', 1.0, 0.9],
#  ['LAL', 'SAS', 1.0, -0.1],
#  ['LAL', 'ORL', 1.0, 7.0],
#  ['LAL', 'MEM', 1.0, 0.7],
#  ['LAL', 'CHI', 1.0, 6.1],
#  ['LAL', 'CLE', 1.0, 6.6],
#  ['LAL', 'MIN', 1.0, -0.3],
#  ['LAL', 'HOU', 1.0, -4.8],
#  ['LAL', 'WAS', 1.0, -2.2],
#  ['LAL', 'BOS', 1.0, 0.5],
#  ['LAL', 'IND', 1.0, 3.8],
#  ['LAL', 'LAC', 1.0, -3.3],
#  ['LAL', 'GSW', 1.0, 6.6],
#  ['LAL', 'BKN', 1.0, 2.2],
#  ['LAL', 'PHX', 1.0, 0.6],
#  ['LAL', 'POR', 1.0, -0.4],
#  ['LAL', 'TOR', 1.0, 0.1],
#  ['LAL', 'UTA', 1.0, 2.7],
#  ['LAL', 'MIL', 0.0, -5.4],
#  ['LAL', 'OKC', 1.0, 2.7],
#  ['LAL', 'SAC', 1.0, 4.4],
#  ['LAL', 'NOP', 1.0, -3.1],
#  ['PHX', 'NYK', 1.0, 6.0],
#  ['PHX', 'ATL', 1.0, 0.1],
#  ['PHX', 'DET', 1.0, 4.7],
#  ['PHX', 'PHI', 0.0, 2.4],
#  ['PHX', 'DEN', 0.0, 1.6],
#  ['PHX', 'DAL', 0.0, -4.2],
#  ['PHX', 'CHA', 1.0, 8.7],
#  ['PHX', 'MIA', 0.0, -0.3],
#  ['PHX', 'SAS', 1.0, -1.3],
#  ['PHX', 'ORL', 0.0, 5.8],
#  ['PHX', 'MEM', 1.0, -0.5],
#  ['PHX', 'CHI', 1.0, 4.8],
#  ['PHX', 'CLE', 1.0, 5.4],
#  ['PHX', 'MIN', 1.0, -1.5],
#  ['PHX', 'HOU', 0.0, -6.0],
#  ['PHX', 'WAS', 1.0, -3.4],
#  ['PHX', 'BOS', 0.0, -0.7],
#  ['PHX', 'IND', 0.0, 2.6],
#  ['PHX', 'LAC', 0.0, -4.5],
#  ['PHX', 'GSW', 1.0, 5.4],
#  ['PHX', 'BKN', 0.0, 0.9],
#  ['PHX', 'LAL', 0.0, -1.9],
#  ['PHX', 'POR', 1.0, -1.6],
#  ['PHX', 'TOR', 0.0, -1.2],
#  ['PHX', 'UTA', 0.0, 1.5],
#  ['PHX', 'MIL', 0.0, -6.6],
#  ['PHX', 'OKC', 0.0, 1.4],
#  ['PHX', 'SAC', 1.0, 3.2],
#  ['PHX', 'NOP', 1.0, -4.3],
#  ['POR', 'NYK', 1.0, 6.9],
#  ['POR', 'ATL', 1.0, 1.1],
#  ['POR', 'DET', 1.0, 5.6],
#  ['POR', 'PHI', 0.0, 3.3],
#  ['POR', 'DEN', 0.0, 2.6],
#  ['POR', 'DAL', 0.0, -3.3],
#  ['POR', 'CHA', 1.0, 9.7],
#  ['POR', 'MIA', 0.0, 0.6],
#  ['POR', 'SAS', 1.0, -0.4],
#  ['POR', 'ORL', 0.0, 6.7],
#  ['POR', 'MEM', 0.0, 0.4],
#  ['POR', 'CHI', 1.0, 5.8],
#  ['POR', 'CLE', 1.0, 6.3],
#  ['POR', 'MIN', 1.0, -0.6],
#  ['POR', 'HOU', 0.0, -5.1],
#  ['POR', 'WAS', 1.0, -2.5],
#  ['POR', 'BOS', 0.0, 0.2],
#  ['POR', 'IND', 0.0, 3.5],
#  ['POR', 'LAC', 0.0, -3.6],
#  ['POR', 'GSW', 1.0, 6.3],
#  ['POR', 'BKN', 0.0, 1.8],
#  ['POR', 'LAL', 0.0, -1.0],
#  ['POR', 'PHX', 0.0, 0.3],
#  ['POR', 'TOR', 0.0, -0.2],
#  ['POR', 'UTA', 0.0, 2.4],
#  ['POR', 'MIL', 0.0, -5.7],
#  ['POR', 'OKC', 0.0, 2.4],
#  ['POR', 'SAC', 1.0, 4.1],
#  ['POR', 'NOP', 0.0, -3.4],
#  ['TOR', 'NYK', 1.0, 6.5],
#  ['TOR', 'ATL', 1.0, 0.6],
#  ['TOR', 'DET', 1.0, 5.2],
#  ['TOR', 'PHI', 1.0, 2.9],
#  ['TOR', 'DEN', 1.0, 2.1],
#  ['TOR', 'DAL', 1.0, -3.7],
#  ['TOR', 'CHA', 1.0, 9.2],
#  ['TOR', 'MIA', 1.0, 0.2],
#  ['TOR', 'SAS', 1.0, -0.8],
#  ['TOR', 'ORL', 1.0, 6.3],
#  ['TOR', 'MEM', 1.0, 0.0],
#  ['TOR', 'CHI', 1.0, 5.3],
#  ['TOR', 'CLE', 1.0, 5.9],
#  ['TOR', 'MIN', 1.0, -1.0],
#  ['TOR', 'HOU', 1.0, -5.5],
#  ['TOR', 'WAS', 1.0, -2.9],
#  ['TOR', 'BOS', 1.0, -0.2],
#  ['TOR', 'IND', 1.0, 3.1],
#  ['TOR', 'LAC', 0.0, -4.0],
#  ['TOR', 'GSW', 1.0, 5.9],
#  ['TOR', 'BKN', 1.0, 1.4],
#  ['TOR', 'LAL', 0.0, -1.4],
#  ['TOR', 'PHX', 1.0, -0.2],
#  ['TOR', 'POR', 1.0, -1.1],
#  ['TOR', 'UTA', 1.0, 2.0],
#  ['TOR', 'MIL', 0.0, -6.1],
#  ['TOR', 'OKC', 1.0, 1.9],
#  ['TOR', 'SAC', 1.0, 3.7],
#  ['TOR', 'NOP', 1.0, -3.8],
#  ['UTA', 'NYK', 1.0, 3.9],
#  ['UTA', 'ATL', 1.0, -2.0],
#  ['UTA', 'DET', 1.0, 2.5],
#  ['UTA', 'PHI', 1.0, 0.3],
#  ['UTA', 'DEN', 1.0, -0.5],
#  ['UTA', 'DAL', 0.0, -6.4],
#  ['UTA', 'CHA', 1.0, 6.6],
#  ['UTA', 'MIA', 0.0, -2.5],
#  ['UTA', 'SAS', 1.0, -3.4],
#  ['UTA', 'ORL', 1.0, 3.6],
#  ['UTA', 'MEM', 1.0, -2.6],
#  ['UTA', 'CHI', 1.0, 2.7],
#  ['UTA', 'CLE', 1.0, 3.3],
#  ['UTA', 'MIN', 1.0, -3.6],
#  ['UTA', 'HOU', 0.0, -8.2],
#  ['UTA', 'WAS', 1.0, -5.5],
#  ['UTA', 'BOS', 0.0, -2.9],
#  ['UTA', 'IND', 1.0, 0.4],
#  ['UTA', 'LAC', 0.0, -6.7],
#  ['UTA', 'GSW', 1.0, 3.2],
#  ['UTA', 'BKN', 1.0, -1.2],
#  ['UTA', 'LAL', 0.0, -4.0],
#  ['UTA', 'PHX', 1.0, -2.8],
#  ['UTA', 'POR', 1.0, -3.7],
#  ['UTA', 'TOR', 0.0, -3.3],
#  ['UTA', 'MIL', 0.0, -8.8],
#  ['UTA', 'OKC', 1.0, -0.7],
#  ['UTA', 'SAC', 1.0, 1.0],
#  ['UTA', 'NOP', 1.0, -6.4],
#  ['MIL', 'NYK', 1.0, 12.0],
#  ['MIL', 'ATL', 1.0, 6.1],
#  ['MIL', 'DET', 1.0, 10.6],
#  ['MIL', 'PHI', 1.0, 8.4],
#  ['MIL', 'DEN', 1.0, 7.6],
#  ['MIL', 'DAL', 1.0, 1.7],
#  ['MIL', 'CHA', 1.0, 14.7],
#  ['MIL', 'MIA', 1.0, 5.7],
#  ['MIL', 'SAS', 1.0, 4.7],
#  ['MIL', 'ORL', 1.0, 11.8],
#  ['MIL', 'MEM', 1.0, 5.5],
#  ['MIL', 'CHI', 1.0, 10.8],
#  ['MIL', 'CLE', 1.0, 11.4],
#  ['MIL', 'MIN', 1.0, 4.5],
#  ['MIL', 'HOU', 1.0, -0.0],
#  ['MIL', 'WAS', 1.0, 2.6],
#  ['MIL', 'BOS', 1.0, 5.3],
#  ['MIL', 'IND', 1.0, 8.6],
#  ['MIL', 'LAC', 1.0, 1.5],
#  ['MIL', 'GSW', 1.0, 11.4],
#  ['MIL', 'BKN', 1.0, 6.9],
#  ['MIL', 'LAL', 1.0, 4.1],
#  ['MIL', 'PHX', 1.0, 5.3],
#  ['MIL', 'POR', 1.0, 4.4],
#  ['MIL', 'TOR', 1.0, 4.8],
#  ['MIL', 'UTA', 1.0, 7.5],
#  ['MIL', 'OKC', 1.0, 7.4],
#  ['MIL', 'SAC', 1.0, 9.1],
#  ['MIL', 'NOP', 1.0, 1.7],
#  ['OKC', 'NYK', 1.0, 3.9],
#  ['OKC', 'ATL', 1.0, -2.0],
#  ['OKC', 'DET', 1.0, 2.5],
#  ['OKC', 'PHI', 0.0, 0.3],
#  ['OKC', 'DEN', 0.0, -0.5],
#  ['OKC', 'DAL', 0.0, -6.3],
#  ['OKC', 'CHA', 1.0, 6.6],
#  ['OKC', 'MIA', 0.0, -2.4],
#  ['OKC', 'SAS', 1.0, -3.4],
#  ['OKC', 'ORL', 1.0, 3.7],
#  ['OKC', 'MEM', 1.0, -2.6],
#  ['OKC', 'CHI', 1.0, 2.7],
#  ['OKC', 'CLE', 1.0, 3.3],
#  ['OKC', 'MIN', 1.0, -3.6],
#  ['OKC', 'HOU', 0.0, -8.1],
#  ['OKC', 'WAS', 1.0, -5.5],
#  ['OKC', 'BOS', 0.0, -2.8],
#  ['OKC', 'IND', 1.0, 0.5],
#  ['OKC', 'LAC', 0.0, -6.6],
#  ['OKC', 'GSW', 1.0, 3.3],
#  ['OKC', 'BKN', 1.0, -1.2],
#  ['OKC', 'LAL', 0.0, -4.0],
#  ['OKC', 'PHX', 1.0, -2.8],
#  ['OKC', 'POR', 1.0, -3.7],
#  ['OKC', 'TOR', 0.0, -3.3],
#  ['OKC', 'UTA', 0.0, -0.6],
#  ['OKC', 'MIL', 0.0, -8.7],
#  ['OKC', 'SAC', 1.0, 1.0],
#  ['OKC', 'NOP', 1.0, -6.4],
#  ['SAC', 'NYK', 1.0, 2.2],
#  ['SAC', 'ATL', 1.0, -3.7],
#  ['SAC', 'DET', 1.0, 0.8],
#  ['SAC', 'PHI', 0.0, -1.4],
#  ['SAC', 'DEN', 0.0, -2.2],
#  ['SAC', 'DAL', 0.0, -8.0],
#  ['SAC', 'CHA', 1.0, 4.9],
#  ['SAC', 'MIA', 0.0, -4.1],
#  ['SAC', 'SAS', 0.0, -5.1],
#  ['SAC', 'ORL', 0.0, 2.0],
#  ['SAC', 'MEM', 0.0, -4.3],
#  ['SAC', 'CHI', 1.0, 1.0],
#  ['SAC', 'CLE', 1.0, 1.6],
#  ['SAC', 'MIN', 1.0, -5.3],
#  ['SAC', 'HOU', 0.0, -9.8],
#  ['SAC', 'WAS', 1.0, -7.2],
#  ['SAC', 'BOS', 0.0, -4.5],
#  ['SAC', 'IND', 0.0, -1.2],
#  ['SAC', 'LAC', 0.0, -8.3],
#  ['SAC', 'GSW', 1.0, 1.6],
#  ['SAC', 'BKN', 0.0, -2.9],
#  ['SAC', 'LAL', 0.0, -5.7],
#  ['SAC', 'PHX', 0.0, -4.5],
#  ['SAC', 'POR', 0.0, -5.4],
#  ['SAC', 'TOR', 0.0, -5.0],
#  ['SAC', 'UTA', 0.0, -2.3],
#  ['SAC', 'MIL', 0.0, -10.4],
#  ['SAC', 'OKC', 0.0, -2.4],
#  ['SAC', 'NOP', 0.0, -8.1],
#  ['NOP', 'NYK', 1.0, 9.6],
#  ['NOP', 'ATL', 1.0, 3.8],
#  ['NOP', 'DET', 1.0, 8.3],
#  ['NOP', 'PHI', 0.0, 6.0],
#  ['NOP', 'DEN', 0.0, 5.3],
#  ['NOP', 'DAL', 0.0, -0.6],
#  ['NOP', 'CHA', 1.0, 12.4],
#  ['NOP', 'MIA', 0.0, 3.3],
#  ['NOP', 'SAS', 1.0, 2.3],
#  ['NOP', 'ORL', 0.0, 9.4],
#  ['NOP', 'MEM', 1.0, 3.1],
#  ['NOP', 'CHI', 1.0, 8.5],
#  ['NOP', 'CLE', 1.0, 9.0],
#  ['NOP', 'MIN', 1.0, 2.1],
#  ['NOP', 'HOU', 0.0, -2.4],
#  ['NOP', 'WAS', 1.0, 0.2],
#  ['NOP', 'BOS', 0.0, 2.9],
#  ['NOP', 'IND', 0.0, 6.2],
#  ['NOP', 'LAC', 0.0, -0.9],
#  ['NOP', 'GSW', 1.0, 9.0],
#  ['NOP', 'BKN', 0.0, 4.6],
#  ['NOP', 'LAL', 0.0, 1.7],
#  ['NOP', 'PHX', 0.0, 3.0],
#  ['NOP', 'POR', 1.0, 2.1],
#  ['NOP', 'TOR', 0.0, 2.5],
#  ['NOP', 'UTA', 0.0, 5.1],
#  ['NOP', 'MIL', 0.0, -3.0],
#  ['NOP', 'OKC', 0.0, 5.1],
#  ['NOP', 'SAC', 1.0, 6.8]]
