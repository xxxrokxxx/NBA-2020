# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import csv
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

nba_team_data = {
 'Team': [],
 'Matchup': [],
 'Game_date': [],
 'W_L': [],
 'Min': [],
 'Pts': [],
 'Fgm': [],
 'Fga': [],
 'Fg_p': [],
 'Three_pm': [],
 'Three_pa': [],
 'Threep_p': [],
 'Ftm': [],
 'Fta': [],
 'Ft_p': [],
 'Oreb': [],
 'Dreb': [],
 'Reb': [],
 'Ast': [],
 'Stl': [],
 'Blk': [],
 'Tov': [],
 'Pf': [],
 'Plus_Minus': []
}

nba_team_prep = {
    'Team1': [],
    'Team2': [],
    ## team1, team2, mean(team1), mean(team2), dif(mean(team1, team 2))
    #
    'Dif_Team1_Team2': [],
    'Win_Loose': [],
    'Point_Diff': []
}

n = pd.read_csv('nba2020.csv')
#format the date and outcome
n['Game_date'] = n['Game_date'].apply(lambda x: datetime.strptime(x.strip(),'%m/%d/%Y'))
n['W_L'] = n['W_L'].apply(lambda x: '1' if x=='W' else '0')

# %%
#Train

#prepare data for win/los
y = n['W_L']
n1 = n.drop('W_L', axis = 1) 
m = n1.to_numpy()
X = m[:,4:]

#prepare data for point difference
mp = n.to_numpy()
X_points = m[:,5:]
y_points = n['Pts']

# %%
teams = n['Team'].unique().tolist()
teams = [x for x in teams]
ntp = nba_team_prep
pairs = [[i, j,'',''] for i in teams for j in teams if i !=j]
ntp = [[i,j,n[(n['Team'] == i)].mean(axis = 0) - n[(n['Team'] == j)].mean(axis = 0),'',''] for i in teams for j in teams if i !=j]

# %%
#Let' try the decision trees

from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor (max_depth=5)
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
#train model for point difference
mp = n.to_numpy()
X_points = m[:,5:]
y_points = n['Pts']
# Out:
# 0       136
# 1       131
# 2       106
# 3       124
# 4        97
#        ...
# 1979    107
# 1980    122
# 1981    130
# 1982    102
# 1983    112
# Name: Pts, Length: 1984, dtype: int64

# %%
tree_reg_points = DecisionTreeRegressor (max_depth=20)
tree_reg_points.fit(X_points,y_points)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=20, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
for game in range(len(pairs)):
    x = (np.asarray(ntp[game][2])[1:]).reshape(1,-1)
    xp = (np.asarray(ntp[game][2])[2:]).reshape(1,-1)
    pairs[game][2] = np.round(tree_reg.predict(x)[0], decimals=1)
    pairs[game][3] = np.round(tree_reg_points.predict(xp)[0], decimals=1)

# %%
pairs
# Out:
# [['NYK', 'ATL', 1.0, 76.0],
#  ['NYK', 'DET', 0.0, 76.0],
#  ['NYK', 'PHI', 0.0, 76.0],
#  ['NYK', 'DEN', 0.0, 76.0],
#  ['NYK', 'DAL', 0.0, 76.0],
#  ['NYK', 'CHA', 1.0, 76.0],
#  ['NYK', 'MIA', 0.0, 76.0],
#  ['NYK', 'SAS', 0.0, 76.0],
#  ['NYK', 'ORL', 0.0, 76.0],
#  ['NYK', 'MEM', 0.0, 76.0],
#  ['NYK', 'CHI', 0.0, 76.0],
#  ['NYK', 'CLE', 1.0, 76.0],
#  ['NYK', 'MIN', 0.0, 76.0],
#  ['NYK', 'HOU', 0.0, 76.0],
#  ['NYK', 'WAS', 0.0, 76.0],
#  ['NYK', 'BOS', 0.0, 76.0],
#  ['NYK', 'IND', 0.0, 76.0],
#  ['NYK', 'LAC', 0.0, 76.0],
#  ['NYK', 'GSW', 1.0, 76.0],
#  ['NYK', 'BKN', 0.0, 76.0],
#  ['NYK', 'LAL', 0.0, 76.0],
#  ['NYK', 'PHX', 0.0, 76.0],
#  ['NYK', 'POR', 0.0, 76.0],
#  ['NYK', 'TOR', 0.0, 76.0],
#  ['NYK', 'UTA', 0.0, 76.0],
#  ['NYK', 'MIL', 0.0, 79.0],
#  ['NYK', 'OKC', 0.0, 76.0],
#  ['NYK', 'SAC', 0.0, 76.0],
#  ['NYK', 'NOP', 0.0, 76.0],
#  ['ATL', 'NYK', 0.0, 76.0],
#  ['ATL', 'DET', 0.0, 76.0],
#  ['ATL', 'PHI', 0.0, 76.0],
#  ['ATL', 'DEN', 0.0, 76.0],
#  ['ATL', 'DAL', 0.0, 76.0],
#  ['ATL', 'CHA', 0.0, 76.0],
#  ['ATL', 'MIA', 0.0, 76.0],
#  ['ATL', 'SAS', 0.0, 76.0],
#  ['ATL', 'ORL', 0.0, 76.0],
#  ['ATL', 'MEM', 0.0, 76.0],
#  ['ATL', 'CHI', 0.0, 76.0],
#  ['ATL', 'CLE', 1.0, 76.0],
#  ['ATL', 'MIN', 0.0, 76.0],
#  ['ATL', 'HOU', 0.0, 76.0],
#  ['ATL', 'WAS', 0.0, 76.0],
#  ['ATL', 'BOS', 0.0, 76.0],
#  ['ATL', 'IND', 0.0, 76.0],
#  ['ATL', 'LAC', 0.0, 76.0],
#  ['ATL', 'GSW', 1.0, 76.0],
#  ['ATL', 'BKN', 0.0, 76.0],
#  ['ATL', 'LAL', 0.0, 76.0],
#  ['ATL', 'PHX', 0.0, 76.0],
#  ['ATL', 'POR', 0.0, 76.0],
#  ['ATL', 'TOR', 0.0, 76.0],
#  ['ATL', 'UTA', 0.0, 76.0],
#  ['ATL', 'MIL', 0.0, 79.0],
#  ['ATL', 'OKC', 0.0, 76.0],
#  ['ATL', 'SAC', 0.0, 76.0],
#  ['ATL', 'NOP', 0.0, 76.0],
#  ['DET', 'NYK', 1.0, 76.0],
#  ['DET', 'ATL', 1.0, 76.0],
#  ['DET', 'PHI', 0.0, 76.0],
#  ['DET', 'DEN', 0.0, 76.0],
#  ['DET', 'DAL', 0.0, 76.0],
#  ['DET', 'CHA', 1.0, 76.0],
#  ['DET', 'MIA', 0.0, 76.0],
#  ['DET', 'SAS', 0.0, 76.0],
#  ['DET', 'ORL', 0.0, 76.0],
#  ['DET', 'MEM', 0.0, 76.0],
#  ['DET', 'CHI', 0.0, 76.0],
#  ['DET', 'CLE', 1.0, 76.0],
#  ['DET', 'MIN', 1.0, 76.0],
#  ['DET', 'HOU', 0.0, 76.0],
#  ['DET', 'WAS', 1.0, 76.0],
#  ['DET', 'BOS', 0.0, 76.0],
#  ['DET', 'IND', 0.0, 76.0],
#  ['DET', 'LAC', 0.0, 76.0],
#  ['DET', 'GSW', 1.0, 76.0],
#  ['DET', 'BKN', 0.0, 76.0],
#  ['DET', 'LAL', 0.0, 76.0],
#  ['DET', 'PHX', 0.0, 76.0],
#  ['DET', 'POR', 0.0, 76.0],
#  ['DET', 'TOR', 0.0, 76.0],
#  ['DET', 'UTA', 0.0, 76.0],
#  ['DET', 'MIL', 0.0, 76.0],
#  ['DET', 'OKC', 0.0, 76.0],
#  ['DET', 'SAC', 0.0, 76.0],
#  ['DET', 'NOP', 0.0, 76.0],
#  ['PHI', 'NYK', 1.0, 76.0],
#  ['PHI', 'ATL', 1.0, 76.0],
#  ['PHI', 'DET', 1.0, 76.0],
#  ['PHI', 'DEN', 0.0, 76.0],
#  ['PHI', 'DAL', 0.0, 76.0],
#  ['PHI', 'CHA', 1.0, 76.0],
#  ['PHI', 'MIA', 0.0, 76.0],
#  ['PHI', 'SAS', 1.0, 76.0],
#  ['PHI', 'ORL', 1.0, 76.0],
#  ['PHI', 'MEM', 1.0, 76.0],
#  ['PHI', 'CHI', 1.0, 76.0],
#  ['PHI', 'CLE', 1.0, 76.0],
#  ['PHI', 'MIN', 1.0, 76.0],
#  ['PHI', 'HOU', 0.0, 76.0],
#  ['PHI', 'WAS', 1.0, 76.0],
#  ['PHI', 'BOS', 0.0, 76.0],
#  ['PHI', 'IND', 1.0, 76.0],
#  ['PHI', 'LAC', 0.0, 76.0],
#  ['PHI', 'GSW', 1.0, 76.0],
#  ['PHI', 'BKN', 1.0, 76.0],
#  ['PHI', 'LAL', 0.0, 76.0],
#  ['PHI', 'PHX', 1.0, 76.0],
#  ['PHI', 'POR', 1.0, 76.0],
#  ['PHI', 'TOR', 0.0, 76.0],
#  ['PHI', 'UTA', 0.0, 76.0],
#  ['PHI', 'MIL', 0.0, 76.0],
#  ['PHI', 'OKC', 1.0, 76.0],
#  ['PHI', 'SAC', 1.0, 76.0],
#  ['PHI', 'NOP', 1.0, 76.0],
#  ['DEN', 'NYK', 1.0, 76.0],
#  ['DEN', 'ATL', 1.0, 76.0],
#  ['DEN', 'DET', 1.0, 76.0],
#  ['DEN', 'PHI', 1.0, 76.0],
#  ['DEN', 'DAL', 0.0, 76.0],
#  ['DEN', 'CHA', 1.0, 76.0],
#  ['DEN', 'MIA', 0.0, 76.0],
#  ['DEN', 'SAS', 1.0, 76.0],
#  ['DEN', 'ORL', 1.0, 76.0],
#  ['DEN', 'MEM', 1.0, 76.0],
#  ['DEN', 'CHI', 1.0, 76.0],
#  ['DEN', 'CLE', 1.0, 76.0],
#  ['DEN', 'MIN', 1.0, 76.0],
#  ['DEN', 'HOU', 0.0, 76.0],
#  ['DEN', 'WAS', 1.0, 76.0],
#  ['DEN', 'BOS', 0.0, 76.0],
#  ['DEN', 'IND', 1.0, 76.0],
#  ['DEN', 'LAC', 0.0, 76.0],
#  ['DEN', 'GSW', 1.0, 76.0],
#  ['DEN', 'BKN', 1.0, 76.0],
#  ['DEN', 'LAL', 0.0, 76.0],
#  ['DEN', 'PHX', 1.0, 76.0],
#  ['DEN', 'POR', 1.0, 76.0],
#  ['DEN', 'TOR', 0.0, 76.0],
#  ['DEN', 'UTA', 0.0, 76.0],
#  ['DEN', 'MIL', 0.0, 76.0],
#  ['DEN', 'OKC', 1.0, 76.0],
#  ['DEN', 'SAC', 1.0, 76.0],
#  ['DEN', 'NOP', 1.0, 76.0],
#  ['DAL', 'NYK', 1.0, 76.0],
#  ['DAL', 'ATL', 1.0, 76.0],
#  ['DAL', 'DET', 1.0, 76.0],
#  ['DAL', 'PHI', 1.0, 76.0],
#  ['DAL', 'DEN', 1.0, 76.0],
#  ['DAL', 'CHA', 1.0, 76.0],
#  ['DAL', 'MIA', 1.0, 76.0],
#  ['DAL', 'SAS', 1.0, 76.0],
#  ['DAL', 'ORL', 1.0, 76.0],
#  ['DAL', 'MEM', 1.0, 76.0],
#  ['DAL', 'CHI', 1.0, 76.0],
#  ['DAL', 'CLE', 1.0, 76.0],
#  ['DAL', 'MIN', 1.0, 76.0],
#  ['DAL', 'HOU', 1.0, 76.0],
#  ['DAL', 'WAS', 1.0, 76.0],
#  ['DAL', 'BOS', 1.0, 76.0],
#  ['DAL', 'IND', 1.0, 76.0],
#  ['DAL', 'LAC', 0.0, 76.0],
#  ['DAL', 'GSW', 1.0, 76.0],
#  ['DAL', 'BKN', 1.0, 76.0],
#  ['DAL', 'LAL', 0.0, 76.0],
#  ['DAL', 'PHX', 1.0, 76.0],
#  ['DAL', 'POR', 1.0, 76.0],
#  ['DAL', 'TOR', 0.0, 76.0],
#  ['DAL', 'UTA', 1.0, 76.0],
#  ['DAL', 'MIL', 0.0, 76.0],
#  ['DAL', 'OKC', 1.0, 76.0],
#  ['DAL', 'SAC', 1.0, 76.0],
#  ['DAL', 'NOP', 1.0, 76.0],
#  ['CHA', 'NYK', 0.0, 76.0],
#  ['CHA', 'ATL', 1.0, 76.0],
#  ['CHA', 'DET', 0.0, 76.0],
#  ['CHA', 'PHI', 0.0, 76.0],
#  ['CHA', 'DEN', 0.0, 76.0],
#  ['CHA', 'DAL', 0.0, 76.0],
#  ['CHA', 'MIA', 0.0, 76.0],
#  ['CHA', 'SAS', 0.0, 76.0],
#  ['CHA', 'ORL', 0.0, 76.0],
#  ['CHA', 'MEM', 0.0, 76.0],
#  ['CHA', 'CHI', 0.0, 76.0],
#  ['CHA', 'CLE', 1.0, 76.0],
#  ['CHA', 'MIN', 0.0, 76.0],
#  ['CHA', 'HOU', 0.0, 76.0],
#  ['CHA', 'WAS', 0.0, 76.0],
#  ['CHA', 'BOS', 0.0, 76.0],
#  ['CHA', 'IND', 0.0, 76.0],
#  ['CHA', 'LAC', 0.0, 76.0],
#  ['CHA', 'GSW', 1.0, 76.0],
#  ['CHA', 'BKN', 0.0, 76.0],
#  ['CHA', 'LAL', 0.0, 76.0],
#  ['CHA', 'PHX', 0.0, 76.0],
#  ['CHA', 'POR', 0.0, 76.0],
#  ['CHA', 'TOR', 0.0, 76.0],
#  ['CHA', 'UTA', 0.0, 76.0],
#  ['CHA', 'MIL', 0.0, 79.0],
#  ['CHA', 'OKC', 0.0, 76.0],
#  ['CHA', 'SAC', 0.0, 76.0],
#  ['CHA', 'NOP', 0.0, 76.0],
#  ['MIA', 'NYK', 1.0, 76.0],
#  ['MIA', 'ATL', 1.0, 76.0],
#  ['MIA', 'DET', 1.0, 76.0],
#  ['MIA', 'PHI', 1.0, 76.0],
#  ['MIA', 'DEN', 1.0, 76.0],
#  ['MIA', 'DAL', 0.0, 76.0],
#  ['MIA', 'CHA', 1.0, 76.0],
#  ['MIA', 'SAS', 1.0, 76.0],
#  ['MIA', 'ORL', 1.0, 76.0],
#  ['MIA', 'MEM', 1.0, 76.0],
#  ['MIA', 'CHI', 1.0, 76.0],
#  ['MIA', 'CLE', 1.0, 76.0],
#  ['MIA', 'MIN', 1.0, 76.0],
#  ['MIA', 'HOU', 0.0, 76.0],
#  ['MIA', 'WAS', 1.0, 76.0],
#  ['MIA', 'BOS', 0.0, 76.0],
#  ['MIA', 'IND', 1.0, 76.0],
#  ['MIA', 'LAC', 0.0, 76.0],
#  ['MIA', 'GSW', 1.0, 76.0],
#  ['MIA', 'BKN', 1.0, 76.0],
#  ['MIA', 'LAL', 0.0, 76.0],
#  ['MIA', 'PHX', 1.0, 76.0],
#  ['MIA', 'POR', 1.0, 76.0],
#  ['MIA', 'TOR', 0.0, 76.0],
#  ['MIA', 'UTA', 1.0, 76.0],
#  ['MIA', 'MIL', 0.0, 76.0],
#  ['MIA', 'OKC', 1.0, 76.0],
#  ['MIA', 'SAC', 1.0, 76.0],
#  ['MIA', 'NOP', 1.0, 76.0],
#  ['SAS', 'NYK', 1.0, 76.0],
#  ['SAS', 'ATL', 1.0, 76.0],
#  ['SAS', 'DET', 1.0, 76.0],
#  ['SAS', 'PHI', 0.0, 76.0],
#  ['SAS', 'DEN', 0.0, 76.0],
#  ['SAS', 'DAL', 0.0, 76.0],
#  ['SAS', 'CHA', 1.0, 76.0],
#  ['SAS', 'MIA', 0.0, 76.0],
#  ['SAS', 'ORL', 0.0, 76.0],
#  ['SAS', 'MEM', 0.0, 76.0],
#  ['SAS', 'CHI', 1.0, 76.0],
#  ['SAS', 'CLE', 1.0, 76.0],
#  ['SAS', 'MIN', 1.0, 76.0],
#  ['SAS', 'HOU', 0.0, 76.0],
#  ['SAS', 'WAS', 1.0, 76.0],
#  ['SAS', 'BOS', 0.0, 76.0],
#  ['SAS', 'IND', 0.0, 76.0],
#  ['SAS', 'LAC', 0.0, 76.0],
#  ['SAS', 'GSW', 1.0, 76.0],
#  ['SAS', 'BKN', 0.0, 76.0],
#  ['SAS', 'LAL', 0.0, 76.0],
#  ['SAS', 'PHX', 0.0, 76.0],
#  ['SAS', 'POR', 0.0, 76.0],
#  ['SAS', 'TOR', 0.0, 76.0],
#  ['SAS', 'UTA', 0.0, 76.0],
#  ['SAS', 'MIL', 0.0, 76.0],
#  ['SAS', 'OKC', 0.0, 76.0],
#  ['SAS', 'SAC', 1.0, 76.0],
#  ['SAS', 'NOP', 0.0, 76.0],
#  ['ORL', 'NYK', 1.0, 76.0],
#  ['ORL', 'ATL', 1.0, 76.0],
#  ['ORL', 'DET', 1.0, 76.0],
#  ['ORL', 'PHI', 0.0, 76.0],
#  ['ORL', 'DEN', 0.0, 76.0],
#  ['ORL', 'DAL', 0.0, 76.0],
#  ['ORL', 'CHA', 1.0, 76.0],
#  ['ORL', 'MIA', 0.0, 76.0],
#  ['ORL', 'SAS', 1.0, 76.0],
#  ['ORL', 'MEM', 1.0, 76.0],
#  ['ORL', 'CHI', 1.0, 76.0],
#  ['ORL', 'CLE', 1.0, 76.0],
#  ['ORL', 'MIN', 1.0, 76.0],
#  ['ORL', 'HOU', 0.0, 76.0],
#  ['ORL', 'WAS', 1.0, 76.0],
#  ['ORL', 'BOS', 0.0, 76.0],
#  ['ORL', 'IND', 0.0, 76.0],
#  ['ORL', 'LAC', 0.0, 76.0],
#  ['ORL', 'GSW', 1.0, 76.0],
#  ['ORL', 'BKN', 0.0, 76.0],
#  ['ORL', 'LAL', 0.0, 76.0],
#  ['ORL', 'PHX', 1.0, 76.0],
#  ['ORL', 'POR', 1.0, 76.0],
#  ['ORL', 'TOR', 0.0, 76.0],
#  ['ORL', 'UTA', 0.0, 76.0],
#  ['ORL', 'MIL', 0.0, 76.0],
#  ['ORL', 'OKC', 0.0, 76.0],
#  ['ORL', 'SAC', 1.0, 76.0],
#  ['ORL', 'NOP', 1.0, 76.0],
#  ['MEM', 'NYK', 1.0, 76.0],
#  ['MEM', 'ATL', 1.0, 76.0],
#  ['MEM', 'DET', 1.0, 76.0],
#  ['MEM', 'PHI', 0.0, 76.0],
#  ['MEM', 'DEN', 0.0, 76.0],
#  ['MEM', 'DAL', 0.0, 76.0],
#  ['MEM', 'CHA', 1.0, 76.0],
#  ['MEM', 'MIA', 0.0, 76.0],
#  ['MEM', 'SAS', 1.0, 76.0],
#  ['MEM', 'ORL', 0.0, 76.0],
#  ['MEM', 'CHI', 1.0, 76.0],
#  ['MEM', 'CLE', 1.0, 76.0],
#  ['MEM', 'MIN', 1.0, 76.0],
#  ['MEM', 'HOU', 0.0, 76.0],
#  ['MEM', 'WAS', 1.0, 76.0],
#  ['MEM', 'BOS', 0.0, 76.0],
#  ['MEM', 'IND', 0.0, 76.0],
#  ['MEM', 'LAC', 0.0, 76.0],
#  ['MEM', 'GSW', 1.0, 76.0],
#  ['MEM', 'BKN', 0.0, 76.0],
#  ['MEM', 'LAL', 0.0, 76.0],
#  ['MEM', 'PHX', 0.0, 76.0],
#  ['MEM', 'POR', 1.0, 76.0],
#  ['MEM', 'TOR', 0.0, 76.0],
#  ['MEM', 'UTA', 0.0, 76.0],
#  ['MEM', 'MIL', 0.0, 76.0],
#  ['MEM', 'OKC', 0.0, 76.0],
#  ['MEM', 'SAC', 1.0, 76.0],
#  ['MEM', 'NOP', 0.0, 76.0],
#  ['CHI', 'NYK', 1.0, 76.0],
#  ['CHI', 'ATL', 1.0, 76.0],
#  ['CHI', 'DET', 1.0, 76.0],
#  ['CHI', 'PHI', 0.0, 76.0],
#  ['CHI', 'DEN', 0.0, 76.0],
#  ['CHI', 'DAL', 0.0, 76.0],
#  ['CHI', 'CHA', 1.0, 76.0],
#  ['CHI', 'MIA', 0.0, 76.0],
#  ['CHI', 'SAS', 0.0, 76.0],
#  ['CHI', 'ORL', 0.0, 76.0],
#  ['CHI', 'MEM', 0.0, 76.0],
#  ['CHI', 'CLE', 1.0, 76.0],
#  ['CHI', 'MIN', 1.0, 76.0],
#  ['CHI', 'HOU', 0.0, 76.0],
#  ['CHI', 'WAS', 1.0, 76.0],
#  ['CHI', 'BOS', 0.0, 76.0],
#  ['CHI', 'IND', 0.0, 76.0],
#  ['CHI', 'LAC', 0.0, 76.0],
#  ['CHI', 'GSW', 1.0, 76.0],
#  ['CHI', 'BKN', 0.0, 76.0],
#  ['CHI', 'LAL', 0.0, 76.0],
#  ['CHI', 'PHX', 0.0, 76.0],
#  ['CHI', 'POR', 0.0, 76.0],
#  ['CHI', 'TOR', 0.0, 76.0],
#  ['CHI', 'UTA', 0.0, 76.0],
#  ['CHI', 'MIL', 0.0, 76.0],
#  ['CHI', 'OKC', 0.0, 76.0],
#  ['CHI', 'SAC', 0.0, 76.0],
#  ['CHI', 'NOP', 0.0, 76.0],
#  ['CLE', 'NYK', 0.0, 76.0],
#  ['CLE', 'ATL', 0.0, 76.0],
#  ['CLE', 'DET', 0.0, 76.0],
#  ['CLE', 'PHI', 0.0, 76.0],
#  ['CLE', 'DEN', 0.0, 76.0],
#  ['CLE', 'DAL', 0.0, 76.0],
#  ['CLE', 'CHA', 0.0, 76.0],
#  ['CLE', 'MIA', 0.0, 76.0],
#  ['CLE', 'SAS', 0.0, 76.0],
#  ['CLE', 'ORL', 0.0, 76.0],
#  ['CLE', 'MEM', 0.0, 76.0],
#  ['CLE', 'CHI', 0.0, 76.0],
#  ['CLE', 'MIN', 0.0, 76.0],
#  ['CLE', 'HOU', 0.0, 76.0],
#  ['CLE', 'WAS', 0.0, 76.0],
#  ['CLE', 'BOS', 0.0, 76.0],
#  ['CLE', 'IND', 0.0, 76.0],
#  ['CLE', 'LAC', 0.0, 76.0],
#  ['CLE', 'GSW', 1.0, 76.0],
#  ['CLE', 'BKN', 0.0, 76.0],
#  ['CLE', 'LAL', 0.0, 76.0],
#  ['CLE', 'PHX', 0.0, 76.0],
#  ['CLE', 'POR', 0.0, 76.0],
#  ['CLE', 'TOR', 0.0, 76.0],
#  ['CLE', 'UTA', 0.0, 76.0],
#  ['CLE', 'MIL', 0.0, 79.0],
#  ['CLE', 'OKC', 0.0, 76.0],
#  ['CLE', 'SAC', 0.0, 76.0],
#  ['CLE', 'NOP', 0.0, 76.0],
#  ['MIN', 'NYK', 1.0, 76.0],
#  ['MIN', 'ATL', 1.0, 76.0],
#  ['MIN', 'DET', 0.0, 76.0],
#  ['MIN', 'PHI', 0.0, 76.0],
#  ['MIN', 'DEN', 0.0, 76.0],
#  ['MIN', 'DAL', 0.0, 76.0],
#  ['MIN', 'CHA', 1.0, 76.0],
#  ['MIN', 'MIA', 0.0, 76.0],
#  ['MIN', 'SAS', 0.0, 76.0],
#  ['MIN', 'ORL', 0.0, 76.0],
#  ['MIN', 'MEM', 0.0, 76.0],
#  ['MIN', 'CHI', 0.0, 76.0],
#  ['MIN', 'CLE', 1.0, 76.0],
#  ['MIN', 'HOU', 0.0, 76.0],
#  ['MIN', 'WAS', 0.0, 76.0],
#  ['MIN', 'BOS', 0.0, 76.0],
#  ['MIN', 'IND', 0.0, 76.0],
#  ['MIN', 'LAC', 0.0, 76.0],
#  ['MIN', 'GSW', 1.0, 76.0],
#  ['MIN', 'BKN', 0.0, 76.0],
#  ['MIN', 'LAL', 0.0, 76.0],
#  ['MIN', 'PHX', 0.0, 76.0],
#  ['MIN', 'POR', 0.0, 76.0],
#  ['MIN', 'TOR', 0.0, 76.0],
#  ['MIN', 'UTA', 0.0, 76.0],
#  ['MIN', 'MIL', 0.0, 76.0],
#  ['MIN', 'OKC', 0.0, 76.0],
#  ['MIN', 'SAC', 0.0, 76.0],
#  ['MIN', 'NOP', 0.0, 76.0],
#  ['HOU', 'NYK', 1.0, 76.0],
#  ['HOU', 'ATL', 1.0, 76.0],
#  ['HOU', 'DET', 1.0, 76.0],
#  ['HOU', 'PHI', 1.0, 76.0],
#  ['HOU', 'DEN', 1.0, 76.0],
#  ['HOU', 'DAL', 0.0, 76.0],
#  ['HOU', 'CHA', 1.0, 76.0],
#  ['HOU', 'MIA', 1.0, 76.0],
#  ['HOU', 'SAS', 1.0, 76.0],
#  ['HOU', 'ORL', 1.0, 76.0],
#  ['HOU', 'MEM', 1.0, 76.0],
#  ['HOU', 'CHI', 1.0, 76.0],
#  ['HOU', 'CLE', 1.0, 76.0],
#  ['HOU', 'MIN', 1.0, 76.0],
#  ['HOU', 'WAS', 1.0, 76.0],
#  ['HOU', 'BOS', 0.0, 76.0],
#  ['HOU', 'IND', 1.0, 76.0],
#  ['HOU', 'LAC', 0.0, 76.0],
#  ['HOU', 'GSW', 1.0, 76.0],
#  ['HOU', 'BKN', 1.0, 76.0],
#  ['HOU', 'LAL', 0.0, 76.0],
#  ['HOU', 'PHX', 1.0, 76.0],
#  ['HOU', 'POR', 1.0, 76.0],
#  ['HOU', 'TOR', 0.0, 76.0],
#  ['HOU', 'UTA', 1.0, 76.0],
#  ['HOU', 'MIL', 0.0, 76.0],
#  ['HOU', 'OKC', 1.0, 76.0],
#  ['HOU', 'SAC', 1.0, 76.0],
#  ['HOU', 'NOP', 1.0, 76.0],
#  ['WAS', 'NYK', 1.0, 76.0],
#  ['WAS', 'ATL', 1.0, 76.0],
#  ['WAS', 'DET', 0.0, 76.0],
#  ['WAS', 'PHI', 0.0, 76.0],
#  ['WAS', 'DEN', 0.0, 76.0],
#  ['WAS', 'DAL', 0.0, 76.0],
#  ['WAS', 'CHA', 1.0, 76.0],
#  ['WAS', 'MIA', 0.0, 76.0],
#  ['WAS', 'SAS', 0.0, 76.0],
#  ['WAS', 'ORL', 0.0, 76.0],
#  ['WAS', 'MEM', 0.0, 76.0],
#  ['WAS', 'CHI', 0.0, 76.0],
#  ['WAS', 'CLE', 1.0, 76.0],
#  ['WAS', 'MIN', 1.0, 76.0],
#  ['WAS', 'HOU', 0.0, 76.0],
#  ['WAS', 'BOS', 0.0, 76.0],
#  ['WAS', 'IND', 0.0, 76.0],
#  ['WAS', 'LAC', 0.0, 76.0],
#  ['WAS', 'GSW', 1.0, 76.0],
#  ['WAS', 'BKN', 0.0, 76.0],
#  ['WAS', 'LAL', 0.0, 76.0],
#  ['WAS', 'PHX', 0.0, 76.0],
#  ['WAS', 'POR', 0.0, 76.0],
#  ['WAS', 'TOR', 0.0, 76.0],
#  ['WAS', 'UTA', 0.0, 76.0],
#  ['WAS', 'MIL', 0.0, 76.0],
#  ['WAS', 'OKC', 0.0, 76.0],
#  ['WAS', 'SAC', 0.0, 76.0],
#  ['WAS', 'NOP', 0.0, 76.0],
#  ['BOS', 'NYK', 1.0, 76.0],
#  ['BOS', 'ATL', 1.0, 76.0],
#  ['BOS', 'DET', 1.0, 76.0],
#  ['BOS', 'PHI', 1.0, 76.0],
#  ['BOS', 'DEN', 1.0, 76.0],
#  ['BOS', 'DAL', 0.0, 76.0],
#  ['BOS', 'CHA', 1.0, 76.0],
#  ['BOS', 'MIA', 1.0, 76.0],
#  ['BOS', 'SAS', 1.0, 76.0],
#  ['BOS', 'ORL', 1.0, 76.0],
#  ['BOS', 'MEM', 1.0, 76.0],
#  ['BOS', 'CHI', 1.0, 76.0],
#  ['BOS', 'CLE', 1.0, 76.0],
#  ['BOS', 'MIN', 1.0, 76.0],
#  ['BOS', 'HOU', 1.0, 76.0],
#  ['BOS', 'WAS', 1.0, 76.0],
#  ['BOS', 'IND', 1.0, 76.0],
#  ['BOS', 'LAC', 0.0, 76.0],
#  ['BOS', 'GSW', 1.0, 76.0],
#  ['BOS', 'BKN', 1.0, 76.0],
#  ['BOS', 'LAL', 0.0, 76.0],
#  ['BOS', 'PHX', 1.0, 76.0],
#  ['BOS', 'POR', 1.0, 76.0],
#  ['BOS', 'TOR', 0.0, 76.0],
#  ['BOS', 'UTA', 1.0, 76.0],
#  ['BOS', 'MIL', 0.0, 76.0],
#  ['BOS', 'OKC', 1.0, 76.0],
#  ['BOS', 'SAC', 1.0, 76.0],
#  ['BOS', 'NOP', 1.0, 76.0],
#  ['IND', 'NYK', 1.0, 76.0],
#  ['IND', 'ATL', 1.0, 76.0],
#  ['IND', 'DET', 1.0, 76.0],
#  ['IND', 'PHI', 0.0, 76.0],
#  ['IND', 'DEN', 0.0, 76.0],
#  ['IND', 'DAL', 0.0, 76.0],
#  ['IND', 'CHA', 1.0, 76.0],
#  ['IND', 'MIA', 0.0, 76.0],
#  ['IND', 'SAS', 1.0, 76.0],
#  ['IND', 'ORL', 1.0, 76.0],
#  ['IND', 'MEM', 1.0, 76.0],
#  ['IND', 'CHI', 1.0, 76.0],
#  ['IND', 'CLE', 1.0, 76.0],
#  ['IND', 'MIN', 1.0, 76.0],
#  ['IND', 'HOU', 0.0, 76.0],
#  ['IND', 'WAS', 1.0, 76.0],
#  ['IND', 'BOS', 0.0, 76.0],
#  ['IND', 'LAC', 0.0, 76.0],
#  ['IND', 'GSW', 1.0, 76.0],
#  ['IND', 'BKN', 1.0, 76.0],
#  ['IND', 'LAL', 0.0, 76.0],
#  ['IND', 'PHX', 1.0, 76.0],
#  ['IND', 'POR', 1.0, 76.0],
#  ['IND', 'TOR', 0.0, 76.0],
#  ['IND', 'UTA', 0.0, 76.0],
#  ['IND', 'MIL', 0.0, 76.0],
#  ['IND', 'OKC', 0.0, 76.0],
#  ['IND', 'SAC', 1.0, 76.0],
#  ['IND', 'NOP', 1.0, 76.0],
#  ['LAC', 'NYK', 1.0, 76.0],
#  ['LAC', 'ATL', 1.0, 76.0],
#  ['LAC', 'DET', 1.0, 76.0],
#  ['LAC', 'PHI', 1.0, 76.0],
#  ['LAC', 'DEN', 1.0, 76.0],
#  ['LAC', 'DAL', 1.0, 76.0],
#  ['LAC', 'CHA', 1.0, 76.0],
#  ['LAC', 'MIA', 1.0, 76.0],
#  ['LAC', 'SAS', 1.0, 76.0],
#  ['LAC', 'ORL', 1.0, 76.0],
#  ['LAC', 'MEM', 1.0, 76.0],
#  ['LAC', 'CHI', 1.0, 76.0],
#  ['LAC', 'CLE', 1.0, 76.0],
#  ['LAC', 'MIN', 1.0, 76.0],
#  ['LAC', 'HOU', 1.0, 76.0],
#  ['LAC', 'WAS', 1.0, 76.0],
#  ['LAC', 'BOS', 1.0, 76.0],
#  ['LAC', 'IND', 1.0, 76.0],
#  ['LAC', 'GSW', 1.0, 76.0],
#  ['LAC', 'BKN', 1.0, 76.0],
#  ['LAC', 'LAL', 0.0, 76.0],
#  ['LAC', 'PHX', 1.0, 76.0],
#  ['LAC', 'POR', 1.0, 76.0],
#  ['LAC', 'TOR', 1.0, 76.0],
#  ['LAC', 'UTA', 1.0, 76.0],
#  ['LAC', 'MIL', 0.0, 76.0],
#  ['LAC', 'OKC', 1.0, 76.0],
#  ['LAC', 'SAC', 1.0, 76.0],
#  ['LAC', 'NOP', 1.0, 76.0],
#  ['GSW', 'NYK', 0.0, 76.0],
#  ['GSW', 'ATL', 0.0, 76.0],
#  ['GSW', 'DET', 0.0, 76.0],
#  ['GSW', 'PHI', 0.0, 76.0],
#  ['GSW', 'DEN', 0.0, 76.0],
#  ['GSW', 'DAL', 0.0, 76.0],
#  ['GSW', 'CHA', 0.0, 76.0],
#  ['GSW', 'MIA', 0.0, 76.0],
#  ['GSW', 'SAS', 0.0, 76.0],
#  ['GSW', 'ORL', 0.0, 76.0],
#  ['GSW', 'MEM', 0.0, 76.0],
#  ['GSW', 'CHI', 0.0, 76.0],
#  ['GSW', 'CLE', 0.0, 76.0],
#  ['GSW', 'MIN', 0.0, 76.0],
#  ['GSW', 'HOU', 0.0, 76.0],
#  ['GSW', 'WAS', 0.0, 76.0],
#  ['GSW', 'BOS', 0.0, 76.0],
#  ['GSW', 'IND', 0.0, 76.0],
#  ['GSW', 'LAC', 0.0, 76.0],
#  ['GSW', 'BKN', 0.0, 76.0],
#  ['GSW', 'LAL', 0.0, 79.0],
#  ['GSW', 'PHX', 0.0, 76.0],
#  ['GSW', 'POR', 0.0, 76.0],
#  ['GSW', 'TOR', 0.0, 76.0],
#  ['GSW', 'UTA', 0.0, 76.0],
#  ['GSW', 'MIL', 0.0, 79.0],
#  ['GSW', 'OKC', 0.0, 76.0],
#  ['GSW', 'SAC', 0.0, 76.0],
#  ['GSW', 'NOP', 0.0, 76.0],
#  ['BKN', 'NYK', 1.0, 76.0],
#  ['BKN', 'ATL', 1.0, 76.0],
#  ['BKN', 'DET', 1.0, 76.0],
#  ['BKN', 'PHI', 0.0, 76.0],
#  ['BKN', 'DEN', 0.0, 76.0],
#  ['BKN', 'DAL', 0.0, 76.0],
#  ['BKN', 'CHA', 1.0, 76.0],
#  ['BKN', 'MIA', 0.0, 76.0],
#  ['BKN', 'SAS', 1.0, 76.0],
#  ['BKN', 'ORL', 1.0, 76.0],
#  ['BKN', 'MEM', 1.0, 76.0],
#  ['BKN', 'CHI', 1.0, 76.0],
#  ['BKN', 'CLE', 1.0, 76.0],
#  ['BKN', 'MIN', 1.0, 76.0],
#  ['BKN', 'HOU', 0.0, 76.0],
#  ['BKN', 'WAS', 1.0, 76.0],
#  ['BKN', 'BOS', 0.0, 76.0],
#  ['BKN', 'IND', 0.0, 76.0],
#  ['BKN', 'LAC', 0.0, 76.0],
#  ['BKN', 'GSW', 1.0, 76.0],
#  ['BKN', 'LAL', 0.0, 76.0],
#  ['BKN', 'PHX', 1.0, 76.0],
#  ['BKN', 'POR', 1.0, 76.0],
#  ['BKN', 'TOR', 0.0, 76.0],
#  ['BKN', 'UTA', 0.0, 76.0],
#  ['BKN', 'MIL', 0.0, 76.0],
#  ['BKN', 'OKC', 0.0, 76.0],
#  ['BKN', 'SAC', 1.0, 76.0],
#  ['BKN', 'NOP', 1.0, 76.0],
#  ['LAL', 'NYK', 1.0, 76.0],
#  ['LAL', 'ATL', 1.0, 76.0],
#  ['LAL', 'DET', 1.0, 76.0],
#  ['LAL', 'PHI', 1.0, 76.0],
#  ['LAL', 'DEN', 1.0, 76.0],
#  ['LAL', 'DAL', 1.0, 76.0],
#  ['LAL', 'CHA', 1.0, 76.0],
#  ['LAL', 'MIA', 1.0, 76.0],
#  ['LAL', 'SAS', 1.0, 76.0],
#  ['LAL', 'ORL', 1.0, 76.0],
#  ['LAL', 'MEM', 1.0, 76.0],
#  ['LAL', 'CHI', 1.0, 76.0],
#  ['LAL', 'CLE', 1.0, 76.0],
#  ['LAL', 'MIN', 1.0, 76.0],
#  ['LAL', 'HOU', 1.0, 76.0],
#  ['LAL', 'WAS', 1.0, 76.0],
#  ['LAL', 'BOS', 1.0, 76.0],
#  ['LAL', 'IND', 1.0, 76.0],
#  ['LAL', 'LAC', 1.0, 76.0],
#  ['LAL', 'GSW', 1.0, 76.0],
#  ['LAL', 'BKN', 1.0, 76.0],
#  ['LAL', 'PHX', 1.0, 76.0],
#  ['LAL', 'POR', 1.0, 76.0],
#  ['LAL', 'TOR', 1.0, 76.0],
#  ['LAL', 'UTA', 1.0, 76.0],
#  ['LAL', 'MIL', 0.0, 76.0],
#  ['LAL', 'OKC', 1.0, 76.0],
#  ['LAL', 'SAC', 1.0, 76.0],
#  ['LAL', 'NOP', 1.0, 76.0],
#  ['PHX', 'NYK', 1.0, 76.0],
#  ['PHX', 'ATL', 1.0, 76.0],
#  ['PHX', 'DET', 1.0, 76.0],
#  ['PHX', 'PHI', 0.0, 76.0],
#  ['PHX', 'DEN', 0.0, 76.0],
#  ['PHX', 'DAL', 0.0, 76.0],
#  ['PHX', 'CHA', 1.0, 76.0],
#  ['PHX', 'MIA', 0.0, 76.0],
#  ['PHX', 'SAS', 1.0, 76.0],
#  ['PHX', 'ORL', 0.0, 76.0],
#  ['PHX', 'MEM', 1.0, 76.0],
#  ['PHX', 'CHI', 1.0, 76.0],
#  ['PHX', 'CLE', 1.0, 76.0],
#  ['PHX', 'MIN', 1.0, 76.0],
#  ['PHX', 'HOU', 0.0, 76.0],
#  ['PHX', 'WAS', 1.0, 76.0],
#  ['PHX', 'BOS', 0.0, 76.0],
#  ['PHX', 'IND', 0.0, 76.0],
#  ['PHX', 'LAC', 0.0, 76.0],
#  ['PHX', 'GSW', 1.0, 76.0],
#  ['PHX', 'BKN', 0.0, 76.0],
#  ['PHX', 'LAL', 0.0, 76.0],
#  ['PHX', 'POR', 1.0, 76.0],
#  ['PHX', 'TOR', 0.0, 76.0],
#  ['PHX', 'UTA', 0.0, 76.0],
#  ['PHX', 'MIL', 0.0, 76.0],
#  ['PHX', 'OKC', 0.0, 76.0],
#  ['PHX', 'SAC', 1.0, 76.0],
#  ['PHX', 'NOP', 1.0, 76.0],
#  ['POR', 'NYK', 1.0, 76.0],
#  ['POR', 'ATL', 1.0, 76.0],
#  ['POR', 'DET', 1.0, 76.0],
#  ['POR', 'PHI', 0.0, 76.0],
#  ['POR', 'DEN', 0.0, 76.0],
#  ['POR', 'DAL', 0.0, 76.0],
#  ['POR', 'CHA', 1.0, 76.0],
#  ['POR', 'MIA', 0.0, 76.0],
#  ['POR', 'SAS', 1.0, 76.0],
#  ['POR', 'ORL', 0.0, 76.0],
#  ['POR', 'MEM', 0.0, 76.0],
#  ['POR', 'CHI', 1.0, 76.0],
#  ['POR', 'CLE', 1.0, 76.0],
#  ['POR', 'MIN', 1.0, 76.0],
#  ['POR', 'HOU', 0.0, 76.0],
#  ['POR', 'WAS', 1.0, 76.0],
#  ['POR', 'BOS', 0.0, 76.0],
#  ['POR', 'IND', 0.0, 76.0],
#  ['POR', 'LAC', 0.0, 76.0],
#  ['POR', 'GSW', 1.0, 76.0],
#  ['POR', 'BKN', 0.0, 76.0],
#  ['POR', 'LAL', 0.0, 76.0],
#  ['POR', 'PHX', 0.0, 76.0],
#  ['POR', 'TOR', 0.0, 76.0],
#  ['POR', 'UTA', 0.0, 76.0],
#  ['POR', 'MIL', 0.0, 76.0],
#  ['POR', 'OKC', 0.0, 76.0],
#  ['POR', 'SAC', 1.0, 76.0],
#  ['POR', 'NOP', 0.0, 76.0],
#  ['TOR', 'NYK', 1.0, 76.0],
#  ['TOR', 'ATL', 1.0, 76.0],
#  ['TOR', 'DET', 1.0, 76.0],
#  ['TOR', 'PHI', 1.0, 76.0],
#  ['TOR', 'DEN', 1.0, 76.0],
#  ['TOR', 'DAL', 1.0, 76.0],
#  ['TOR', 'CHA', 1.0, 76.0],
#  ['TOR', 'MIA', 1.0, 76.0],
#  ['TOR', 'SAS', 1.0, 76.0],
#  ['TOR', 'ORL', 1.0, 76.0],
#  ['TOR', 'MEM', 1.0, 76.0],
#  ['TOR', 'CHI', 1.0, 76.0],
#  ['TOR', 'CLE', 1.0, 76.0],
#  ['TOR', 'MIN', 1.0, 76.0],
#  ['TOR', 'HOU', 1.0, 76.0],
#  ['TOR', 'WAS', 1.0, 76.0],
#  ['TOR', 'BOS', 1.0, 76.0],
#  ['TOR', 'IND', 1.0, 76.0],
#  ['TOR', 'LAC', 0.0, 76.0],
#  ['TOR', 'GSW', 1.0, 76.0],
#  ['TOR', 'BKN', 1.0, 76.0],
#  ['TOR', 'LAL', 0.0, 76.0],
#  ['TOR', 'PHX', 1.0, 76.0],
#  ['TOR', 'POR', 1.0, 76.0],
#  ['TOR', 'UTA', 1.0, 76.0],
#  ['TOR', 'MIL', 0.0, 76.0],
#  ['TOR', 'OKC', 1.0, 76.0],
#  ['TOR', 'SAC', 1.0, 76.0],
#  ['TOR', 'NOP', 1.0, 76.0],
#  ['UTA', 'NYK', 1.0, 76.0],
#  ['UTA', 'ATL', 1.0, 76.0],
#  ['UTA', 'DET', 1.0, 76.0],
#  ['UTA', 'PHI', 1.0, 76.0],
#  ['UTA', 'DEN', 1.0, 76.0],
#  ['UTA', 'DAL', 0.0, 76.0],
#  ['UTA', 'CHA', 1.0, 76.0],
#  ['UTA', 'MIA', 0.0, 76.0],
#  ['UTA', 'SAS', 1.0, 76.0],
#  ['UTA', 'ORL', 1.0, 76.0],
#  ['UTA', 'MEM', 1.0, 76.0],
#  ['UTA', 'CHI', 1.0, 76.0],
#  ['UTA', 'CLE', 1.0, 76.0],
#  ['UTA', 'MIN', 1.0, 76.0],
#  ['UTA', 'HOU', 0.0, 76.0],
#  ['UTA', 'WAS', 1.0, 76.0],
#  ['UTA', 'BOS', 0.0, 76.0],
#  ['UTA', 'IND', 1.0, 76.0],
#  ['UTA', 'LAC', 0.0, 76.0],
#  ['UTA', 'GSW', 1.0, 76.0],
#  ['UTA', 'BKN', 1.0, 76.0],
#  ['UTA', 'LAL', 0.0, 76.0],
#  ['UTA', 'PHX', 1.0, 76.0],
#  ['UTA', 'POR', 1.0, 76.0],
#  ['UTA', 'TOR', 0.0, 76.0],
#  ['UTA', 'MIL', 0.0, 76.0],
#  ['UTA', 'OKC', 1.0, 76.0],
#  ['UTA', 'SAC', 1.0, 76.0],
#  ['UTA', 'NOP', 1.0, 76.0],
#  ['MIL', 'NYK', 1.0, 76.0],
#  ['MIL', 'ATL', 1.0, 76.0],
#  ['MIL', 'DET', 1.0, 76.0],
#  ['MIL', 'PHI', 1.0, 76.0],
#  ['MIL', 'DEN', 1.0, 76.0],
#  ['MIL', 'DAL', 1.0, 76.0],
#  ['MIL', 'CHA', 1.0, 76.0],
#  ['MIL', 'MIA', 1.0, 76.0],
#  ['MIL', 'SAS', 1.0, 76.0],
#  ['MIL', 'ORL', 1.0, 76.0],
#  ['MIL', 'MEM', 1.0, 76.0],
#  ['MIL', 'CHI', 1.0, 76.0],
#  ['MIL', 'CLE', 1.0, 76.0],
#  ['MIL', 'MIN', 1.0, 76.0],
#  ['MIL', 'HOU', 1.0, 76.0],
#  ['MIL', 'WAS', 1.0, 76.0],
#  ['MIL', 'BOS', 1.0, 76.0],
#  ['MIL', 'IND', 1.0, 76.0],
#  ['MIL', 'LAC', 1.0, 76.0],
#  ['MIL', 'GSW', 1.0, 76.0],
#  ['MIL', 'BKN', 1.0, 76.0],
#  ['MIL', 'LAL', 1.0, 76.0],
#  ['MIL', 'PHX', 1.0, 76.0],
#  ['MIL', 'POR', 1.0, 76.0],
#  ['MIL', 'TOR', 1.0, 76.0],
#  ['MIL', 'UTA', 1.0, 76.0],
#  ['MIL', 'OKC', 1.0, 76.0],
#  ['MIL', 'SAC', 1.0, 76.0],
#  ['MIL', 'NOP', 1.0, 76.0],
#  ['OKC', 'NYK', 1.0, 76.0],
#  ['OKC', 'ATL', 1.0, 76.0],
#  ['OKC', 'DET', 1.0, 76.0],
#  ['OKC', 'PHI', 0.0, 76.0],
#  ['OKC', 'DEN', 0.0, 76.0],
#  ['OKC', 'DAL', 0.0, 76.0],
#  ['OKC', 'CHA', 1.0, 76.0],
#  ['OKC', 'MIA', 0.0, 76.0],
#  ['OKC', 'SAS', 1.0, 76.0],
#  ['OKC', 'ORL', 1.0, 76.0],
#  ['OKC', 'MEM', 1.0, 76.0],
#  ['OKC', 'CHI', 1.0, 76.0],
#  ['OKC', 'CLE', 1.0, 76.0],
#  ['OKC', 'MIN', 1.0, 76.0],
#  ['OKC', 'HOU', 0.0, 76.0],
#  ['OKC', 'WAS', 1.0, 76.0],
#  ['OKC', 'BOS', 0.0, 76.0],
#  ['OKC', 'IND', 1.0, 76.0],
#  ['OKC', 'LAC', 0.0, 76.0],
#  ['OKC', 'GSW', 1.0, 76.0],
#  ['OKC', 'BKN', 1.0, 76.0],
#  ['OKC', 'LAL', 0.0, 76.0],
#  ['OKC', 'PHX', 1.0, 76.0],
#  ['OKC', 'POR', 1.0, 76.0],
#  ['OKC', 'TOR', 0.0, 76.0],
#  ['OKC', 'UTA', 0.0, 76.0],
#  ['OKC', 'MIL', 0.0, 76.0],
#  ['OKC', 'SAC', 1.0, 76.0],
#  ['OKC', 'NOP', 1.0, 76.0],
#  ['SAC', 'NYK', 1.0, 76.0],
#  ['SAC', 'ATL', 1.0, 76.0],
#  ['SAC', 'DET', 1.0, 76.0],
#  ['SAC', 'PHI', 0.0, 76.0],
#  ['SAC', 'DEN', 0.0, 76.0],
#  ['SAC', 'DAL', 0.0, 76.0],
#  ['SAC', 'CHA', 1.0, 76.0],
#  ['SAC', 'MIA', 0.0, 76.0],
#  ['SAC', 'SAS', 0.0, 76.0],
#  ['SAC', 'ORL', 0.0, 76.0],
#  ['SAC', 'MEM', 0.0, 76.0],
#  ['SAC', 'CHI', 1.0, 76.0],
#  ['SAC', 'CLE', 1.0, 76.0],
#  ['SAC', 'MIN', 1.0, 76.0],
#  ['SAC', 'HOU', 0.0, 76.0],
#  ['SAC', 'WAS', 1.0, 76.0],
#  ['SAC', 'BOS', 0.0, 76.0],
#  ['SAC', 'IND', 0.0, 76.0],
#  ['SAC', 'LAC', 0.0, 76.0],
#  ['SAC', 'GSW', 1.0, 76.0],
#  ['SAC', 'BKN', 0.0, 76.0],
#  ['SAC', 'LAL', 0.0, 76.0],
#  ['SAC', 'PHX', 0.0, 76.0],
#  ['SAC', 'POR', 0.0, 76.0],
#  ['SAC', 'TOR', 0.0, 76.0],
#  ['SAC', 'UTA', 0.0, 76.0],
#  ['SAC', 'MIL', 0.0, 76.0],
#  ['SAC', 'OKC', 0.0, 76.0],
#  ['SAC', 'NOP', 0.0, 76.0],
#  ['NOP', 'NYK', 1.0, 76.0],
#  ['NOP', 'ATL', 1.0, 76.0],
#  ['NOP', 'DET', 1.0, 76.0],
#  ['NOP', 'PHI', 0.0, 76.0],
#  ['NOP', 'DEN', 0.0, 76.0],
#  ['NOP', 'DAL', 0.0, 76.0],
#  ['NOP', 'CHA', 1.0, 76.0],
#  ['NOP', 'MIA', 0.0, 76.0],
#  ['NOP', 'SAS', 1.0, 76.0],
#  ['NOP', 'ORL', 0.0, 76.0],
#  ['NOP', 'MEM', 1.0, 76.0],
#  ['NOP', 'CHI', 1.0, 76.0],
#  ['NOP', 'CLE', 1.0, 76.0],
#  ['NOP', 'MIN', 1.0, 76.0],
#  ['NOP', 'HOU', 0.0, 76.0],
#  ['NOP', 'WAS', 1.0, 76.0],
#  ['NOP', 'BOS', 0.0, 76.0],
#  ['NOP', 'IND', 0.0, 76.0],
#  ['NOP', 'LAC', 0.0, 76.0],
#  ['NOP', 'GSW', 1.0, 76.0],
#  ['NOP', 'BKN', 0.0, 76.0],
#  ['NOP', 'LAL', 0.0, 76.0],
#  ['NOP', 'PHX', 0.0, 76.0],
#  ['NOP', 'POR', 1.0, 76.0],
#  ['NOP', 'TOR', 0.0, 76.0],
#  ['NOP', 'UTA', 0.0, 76.0],
#  ['NOP', 'MIL', 0.0, 76.0],
#  ['NOP', 'OKC', 0.0, 76.0],
#  ['NOP', 'SAC', 1.0, 76.0]]
